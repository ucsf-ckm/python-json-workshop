# %% [markdown]
# ### Request JSON data from an API endpoint
#
# In this section, we will use the **requests** module to obtain JSON data from an api endpoint supplied by the UCSF Profiles application.  Because python can easily retrieve JSON data as a dictionary structure, we will be able to use techniques for python dictionaries to parse and analyze the information.

# %% [markdown]
# ### A note on this data...
#
# The service we will use in this section is an api provided by the UCSF Profiles application.
#
# http://profiles.ucsf.edu/about/ForDevelopers.aspx
#
# You might want to take a few minutes to visit this site, follow the "learn more and get started" link, and read about the service, the api, and how different apps are using it.
#
# For this tutorial, we'll use the sample JSON link provided by the documentation:
#
# http://api.profiles.ucsf.edu/json/v2/?ProfilesURLName=kirsten.bibbins-domingo&source=YourURLGoesHere&publications=full
#
# First, let's start by importing the requests module to retrieve data from the web.

# %%
import requests

# %% [markdown]
# We will use on a small part of this library - you may want to look through the tutorial and documentation at http://docs.python-requests.org/en/master/.
#
# You can pass request parameters to the web service through the URL itself or through a payload.  Both will work, though the payload approach can be useful when the amount of data you need to send to the URL becomes unwieldy.  Both approaches are shown below, though the direct inclusion in the URL method is commented out.

# %%
#url = 'https://rxnav.nlm.nih.gov/REST/spellingsuggestions.json?name=ambienn'
#url = 'http://api.profiles.ucsf.edu/json/v2/?ProfilesURLName=kirsten.bibbins-domingo&source=YourURLGoesHere&publications=full'
url = 'http://api.profiles.ucsf.edu/json/v2/'
payload = {'ProfilesURLName': 'kirsten.bibbins-domingo', 'source':'YourURLGoesHere', 'publications':'full'}

# %%
# r = requests.get(url)
r = requests.get(url, payload)

# %% [markdown]
# The requests module provides a method to view the resulting url from a payload - this can also be useful if you'd like to look at the page directly in your browser.

# %%
r.url
# Out:
# 'http://api.profiles.ucsf.edu/json/v2/?source=YourURLGoesHere&ProfilesURLName=kirsten.bibbins-domingo&publications=full'

# %% [markdown]
# And convert it to JSON

# %%
data = r.json()

# %%
data
# Out:
# {'Profiles': [{'Address': {'Address1': '550 16th. Street',
#     'Address2': 'San Francisco, CA 94158',
#     'Address3': None,
#     'Address4': None,
#     'Fax': '415-514-8150',
#     'Latitude': '37.755637',
#     'Longitude': '-122.405102',
#     'Telephone': '415-502-4106'},
#    'AwardOrHonors': [{'AwardConferredBy': None,
#      'AwardEndDate': None,
#      'AwardLabel': 'Association of American Physicians',
#      'AwardStartDate': '2017',
#      'Summary': 'Association of American Physicians, 2017'},
#     {'AwardConferredBy': None,
#      'AwardEndDate': None,
#      'AwardLabel': 'National Academy of Medicine',
#      'AwardStartDate': '2015',
#      'Summary': 'National Academy of Medicine, 2015'},
#     {'AwardConferredBy': None,
#      'AwardEndDate': None,
#      'AwardLabel': 'Mid-career Research Mentor Award - Society of General Internal Medicine',
#      'AwardStartDate': '2014',
#      'Summary': 'Mid-career Research Mentor Award - Society of General Internal Medicine, 2014'},
#     {'AwardConferredBy': None,
#      'AwardEndDate': None,
#      'AwardLabel': 'Lee Goldman, MD Endowed Chair in Medicine',
#      'AwardStartDate': '2012',
#      'Summary': 'Lee Goldman, MD Endowed Chair in Medicine, 2012'},
#     {'AwardConferredBy': None,
#      'AwardEndDate': None,
#      'AwardLabel': 'American Society for Clinical Investigation',
#      'AwardStartDate': '2010',
#      'Summary': 'American Society for Clinical Investigation, 2010'}],
#    'Department': 'Epidemiology & Biostatistics',
#    'Education_Training': [{'degree': 'MAS',
#      'department_or_school': 'Epidemiology and Biostatistics',
#      'end_date': '2004',
#      'organization': 'University of California, San Francisco',
#      'start_date': ''},
#     {'degree': 'Residency',
#      'department_or_school': 'Medicine',
#      'end_date': '2001',
#      'organization': 'University of California, San Francisco',
#      'start_date': ''},
#     {'degree': 'MD',
#      'department_or_school': 'Medicine',
#      'end_date': '1999',
#      'organization': 'University of California, San Francisco',
#      'start_date': ''},
#     {'degree': 'PhD',
#      'department_or_school': 'Graduate Division (Biochemistry)',
#      'end_date': '1994',
#      'organization': 'University of California, San Francisco',
#      'start_date': ''},
#     {'degree': 'AB',
#      'department_or_school': 'Molecular Biology',
#      'end_date': '1987',
#      'organization': 'Princeton University',
#      'start_date': ''}],
#    'Email': 'kirsten.bibbins-domingo@ucsf.edu',
#    'FirstName': 'Kirsten',
#    'FreetextKeywords': ['Chronic disease prevention',
#     'Cardiovascular disease',
#     'Health of young adults',
#     'Kidney disease',
#     'Health disparities'],
#    'GlobalHealth_beta': {'Countries': ['Argentina',
#      'Chile',
#      'China',
#      'Mexico',
#      'Puerto Rico',
#      'United States']},
#    'Keywords': ['Primary Prevention',
#     'Cardiovascular Diseases',
#     'Hypertension',
#     'Advisory Committees',
#     'Mass Screening'],
#    'LastName': 'Bibbins-Domingo',
#    'MediaLinks_beta': [{'Date': '2017-08-22',
#      'Label': 'UCSF to Lead Gathering of Important Health Information for Sexual, Gender Minorities',
#      'URL': 'https://www.ucsf.edu/news/2017/08/408116/ucsf-lead-gathering-important-health-information-sexual-gender-minorities'},
#     {'Date': '2017-07-21',
#      'Label': 'Kirsten Bibbins-Domingo, PhD, MD, MAS Appointed as Chair of Epidemiology and Biostatistics and Inaugural Vice Dean for Population Health and Health Equity',
#      'URL': 'https://medschool.ucsf.edu/kirsten-bibbins-domingo-phd-md-mas-appointed-chair-epidemiology-and-biostatistics-and-inaugural-vice'},
#     {'Date': '2017-04-17',
#      'Label': 'KQED Forum with Michael Krasny',
#      'URL': 'https://ww2.kqed.org/forum/2017/04/14/new-guidelines-let-patients-opt-in-to-controversial-prostate-cancer-screening/'},
#     {'Date': '2017-02-07',
#      'Label': 'In Decade Since Founding, UCSF’s Center for Vulnerable Populations Has Innovated Research, Care',
#      'URL': 'https://www.ucsf.edu/news/2017/02/405736/decade-founding-ucsfs-center-vulnerable-populations-has-innovated-research-care'},
#     {'Date': '2016-11-01',
#      'Label': 'Do soda taxes work? Experts look to Mexico',
#      'URL': 'http://www.cnn.com/2016/11/01/health/soda-tax-benefits-mexico/index.html'},
#     {'Date': '2016-09-15',
#      'Label': 'In a first, aspirin is recommended to fight a form of cancer',
#      'URL': 'http://well.blogs.nytimes.com/2015/09/14/in-a-first-aspirin-is-recommended-to-fight-a-form-of-cancer/?_r=0'},
#     {'Date': '2016-08-26',
#      'Label': 'Cost of New Cholesterol Drug Unsustainable',
#      'URL': 'https://www.ucsf.edu/news/2016/08/403891/cost-new-cholesterol-drugs-unsustainable-says-study'},
#     {'Date': '2015-06-25',
#      'Label': 'UCSF Researchers Launch Landmark Study of LGBTQ Community Health',
#      'URL': 'https://www.ucsf.edu/news/2015/06/130631/ucsf-researchers-launch-landmark-study-lgbtq-community-health'},
#     {'Date': '2015-04-29',
#      'Label': 'New breast cancer screening guidelines explained',
#      'URL': 'http://www.washingtonpost.com/news/to-your-health/wp/2015/04/29/new-breast-cancer-screening-guidelines-explained/'},
#     {'Date': '2015-04-20',
#      'Label': 'Statin Use in Elderly Would Prevent Disease But Could Carry Considerable Side Effects',
#      'URL': 'http://www.ucsf.edu/news/2015/04/125236/statin-use-elderly-would-prevent-disease-could-carry-considerable-side-effects'},
#     {'Date': '2014-11-10',
#      'Label': 'SFSU and UCSF Awarded $17 Million to Increase Diversity in the Biomedical',
#      'URL': 'http://ctsi.ucsf.edu/news/about-ctsi/sfsu-and-ucsf-awarded-17-million-increase-diversity-biomedical-workforce'},
#     {'Date': '2014-10-23',
#      'Label': 'S.F. State receives $17 million grant to help minorities',
#      'URL': 'http://www.sfgate.com/education/article/S-F-State-receives-17-million-grant-to-help-5843661.php'},
#     {'Date': '2014-01-05',
#      'Label': "Bay Area's People to Watch in 2014",
#      'URL': 'http://www.sfgate.com/bayarea/article/Bay-Area-s-People-to-Watch-in-2014-5114765.php'},
#     {'Date': '2013-06-04',
#      'Label': "Q&A With Director of UCSF's K Scholars Program",
#      'URL': 'http://www.ucsf.edu/news/2013/06/106411/qa-co-director-ucsf-k-scholars-program'},
#     {'Date': '2013-02-11',
#      'Label': 'Reducing Sodium in American Diet Would Save Hundreds of Thousands of Lives',
#      'URL': 'http://www.ucsf.edu/news/2013/02/13516/reducing-sodium-american-diet-would-save-hundreds-thousands-lives'},
#     {'Date': '2012-09-04',
#      'Label': 'Undergraduates Get Hands-On Experience with Clinical Research',
#      'URL': 'http://www.ucsf.edu/news/2012/09/12662/undergraduates-get-hands-experience-clinical-research'},
#     {'Date': '2012-01-09',
#      'Label': 'How Many Lives Could a Soda Tax Save?',
#      'URL': 'http://www.ucsf.edu/news/2012/01/11267/how-many-lives-could-soda-tax-save'}],
#    'NIHGrants_beta': [{'NIHFiscalYear': '2018',
#      'NIHProjectNumber': 'OT2OD025276',
#      'Title': 'All of Us Research Program National Sexual and Gender Minority Engagement Network',
#      'api_notes': 'Deprecated, use ResearchActivitiesAndFunding instead. The fiscal year may be off.'}],
#    'Name': 'Kirsten Bibbins-Domingo, MD, PhD, MAS',
#    'Narrative': 'Kirsten Bibbins-Domingo, PhD, MD, MAS is the Lee Goldman, MD Endowed Chair in Medicine and Professor of Epidemiology and Biostatistics and Medicine. She is the Vice Dean for Population Health and Health Equity in the UCSF School of Medicine, and she directs the UCSF Center for Vulnerable Populations at Zuckerberg San Francisco General Hospital, a research center focused on discovery, implementation, policy, advocacy, and community engagement for communities at risk for poor health and inadequate healthcare.  She is the Director of the CTSI Clinical and Translational Science Training (CTST) Programs.  A general internist at Zuckerberg San Francisco General Hospital, Dr. Bibbins-Domingo has expertise in cardiovascular disease, diabetes, and chronic kidney disease with a particular interest in the development of chronic disease in young adults.  Her work focuses on racial, ethnic and income differences in manifestations of chronic disease and effective clinical, public health, and policy interventions aimed at prevention.  She leads the UCSF computer simulation modeling group using the Cardiovascular Disease Policy Model.  Dr. Bibbins-Domingo is the PI or joint PI of three collaborative center grants from the NIH: the NIMHD P60 Center for Health And Risk in Minority youth and adults (CHARM) addressing disparities in chronic disease in youth and young adults, Bring It Down  an NINDS U54 research center addressing stroke prevention and stroke disparities in collaboration with Kaiser Permanente Northern California, and BUILD  a NIGMS U54 infrastructure and training grant with San Francisco State University.  She has been a member of the US Preventive Services Task Force since 2010 and is the Immediate Past Chair. She is a member of the American Society for Clinical Investigation, the National Academy of Medicine, and the Association of American Physicians.',
#    'PhotoURL': 'http://profiles.ucsf.edu/profile/Modules/CustomViewPersonGeneralInfo/PhotoHandler.ashx?NodeID=370012',
#    'ProfilesURL': 'http://profiles.ucsf.edu/kirsten.bibbins-domingo',
#    'PublicationCount': '218',
#    'Publications': [{'AuthorList': 'Hiatt RA, Handley MA, Ling PM, Burchard E, Thakur N, Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2017-09-01T00:00:00',
#      'Featured': None,
#      'Publication': 'American journal of preventive medicine',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/173083677',
#      'PublicationMedlineTA': 'Am J Prev Med',
#      'PublicationSource': [{'PMID': '28818252',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28818252'}],
#      'PublicationTitle': 'Hiatt RA, Handley MA, Ling PM, Burchard E, Thakur N, Bibbins-Domingo K. Origins of Cancer Disparities in Young Adults: Logic Models to Guide Research. Am J Prev Med. 2017 Sep; 53(3S1):S95-S102.',
#      'Title': 'Origins of Cancer Disparities in Young Adults: Logic Models to Guide Research.',
#      'Year': '2017'},
#     {'AuthorList': 'Ling PM, Holmes LM, Jordan JW, Lisha NE, Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2017-09-01T00:00:00',
#      'Featured': None,
#      'Publication': 'American journal of preventive medicine',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/173083678',
#      'PublicationMedlineTA': 'Am J Prev Med',
#      'PublicationSource': [{'PMID': '28818250',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28818250'}],
#      'PublicationTitle': 'Ling PM, Holmes LM, Jordan JW, Lisha NE, Bibbins-Domingo K. Bars, Nightclubs, and Cancer Prevention: New Approaches to Reduce Young Adult Cigarette Smoking. Am J Prev Med. 2017 Sep; 53(3S1):S78-S85.',
#      'Title': 'Bars, Nightclubs, and Cancer Prevention: New Approaches to Reduce Young Adult Cigarette Smoking.',
#      'Year': '2017'},
#     {'AuthorList': 'Schillinger D, Ling PM, Fine S, Boyer CB, Rogers E, Vargas RA, Bibbins-Domingo K, Chou WS',
#      'Claimed': True,
#      'Date': '2017-09-01T00:00:00',
#      'Featured': None,
#      'Publication': 'American journal of preventive medicine',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/173083679',
#      'PublicationMedlineTA': 'Am J Prev Med',
#      'PublicationSource': [{'PMID': '28818240',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28818240'}],
#      'PublicationTitle': 'Schillinger D, Ling PM, Fine S, Boyer CB, Rogers E, Vargas RA, Bibbins-Domingo K, Chou WS. Reducing Cancer and Cancer Disparities: Lessons From a Youth-Generated Diabetes Prevention Campaign. Am J Prev Med. 2017 Sep; 53(3S1):S103-S113.',
#      'Title': 'Reducing Cancer and Cancer Disparities: Lessons From a Youth-Generated Diabetes Prevention Campaign.',
#      'Year': '2017'},
#     {'AuthorList': 'Ishida JH, Auer R, Vittinghoff E, Pletcher MJ, Reis JP, Sidney S, Johansen KL, Bibbins-Domingo K, Peralta CA, Shlipak MG',
#      'Claimed': True,
#      'Date': '2017-08-24T00:00:00',
#      'Featured': None,
#      'Publication': 'Clinical journal of the American Society of Nephrology : CJASN',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/173610838',
#      'PublicationMedlineTA': 'Clin J Am Soc Nephrol',
#      'PublicationSource': [{'PMID': '28838990',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28838990'}],
#      'PublicationTitle': 'Ishida JH, Auer R, Vittinghoff E, Pletcher MJ, Reis JP, Sidney S, Johansen KL, Bibbins-Domingo K, Peralta CA, Shlipak MG. Marijuana Use and Estimated Glomerular Filtration Rate in Young Adults. Clin J Am Soc Nephrol. 2017 Aug 24.',
#      'Title': 'Marijuana Use and Estimated Glomerular Filtration Rate in Young Adults.',
#      'Year': '2017'},
#     {'AuthorList': 'Kazi DS, Penko J, Coxson PG, Moran AE, Ollendorf DA, Tice JA, Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2017-08-22T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/173083676',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28829863',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28829863'}],
#      'PublicationTitle': 'Kazi DS, Penko J, Coxson PG, Moran AE, Ollendorf DA, Tice JA, Bibbins-Domingo K. Updated Cost-effectiveness Analysis of PCSK9 Inhibitors Based on the Results of the FOURIER Trial. JAMA. 2017 08 22; 318(8):748-750.',
#      'Title': 'Updated Cost-effectiveness Analysis of PCSK9 Inhibitors Based on the Results of the FOURIER Trial.',
#      'Year': '2017'},
#     {'AuthorList': 'Grossman DC, Bibbins-Domingo K, Curry SJ',
#      'Claimed': True,
#      'Date': '2017-07-18T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/169890782',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28719688',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28719688'}],
#      'PublicationTitle': 'Grossman DC, Bibbins-Domingo K, Curry SJ. Screening Pelvic Examinations-Reply. JAMA. 2017 07 18; 318(3):300-301.',
#      'Title': 'Screening Pelvic Examinations-Reply.',
#      'Year': '2017'},
#     {'AuthorList': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#      'Claimed': True,
#      'Date': '2017-07-11T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/167533420',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28697260',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28697260'}],
#      'PublicationTitle': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW. Behavioral Counseling to Promote a Healthful Diet and Physical Activity for Cardiovascular Disease Prevention in Adults Without Cardiovascular Risk Factors: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Jul 11; 318(2):167-174.',
#      'Title': 'Behavioral Counseling to Promote a Healthful Diet and Physical Activity for Cardiovascular Disease Prevention in Adults Without Cardiovascular Risk Factors: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2017'},
#     {'AuthorList': 'Heller DJ, Coxson PG, Penko J, Pletcher MJ, Goldman L, Odden MC, Kazi DS, Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2017-07-07T00:00:00',
#      'Featured': None,
#      'Publication': 'Circulation',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/167120746',
#      'PublicationMedlineTA': 'Circulation',
#      'PublicationSource': [{'PMID': '28687710',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28687710'}],
#      'PublicationTitle': 'Heller DJ, Coxson PG, Penko J, Pletcher MJ, Goldman L, Odden MC, Kazi DS, Bibbins-Domingo K. Evaluating the Impact and Cost-Effectiveness of Statin Use Guidelines for Primary Prevention of Coronary Heart Disease and Stroke. Circulation. 2017 Sep 19; 136(12):1087-1098.',
#      'Title': 'Evaluating the Impact and Cost-Effectiveness of Statin Use Guidelines for Primary Prevention of Coronary Heart Disease and Stroke.',
#      'Year': '2017'},
#     {'AuthorList': 'Pignone MP, Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2017-07-01T00:00:00',
#      'Featured': None,
#      'Publication': 'The Medical clinics of North America',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/162263092',
#      'PublicationMedlineTA': 'Med Clin North Am',
#      'PublicationSource': [{'PMID': '28577631',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28577631'}],
#      'PublicationTitle': 'Pignone MP, Bibbins-Domingo K. Update on Key Clinical Preventive Services for Adults. Med Clin North Am. 2017 Jul; 101(4):xvii-xix.',
#      'Title': 'Update on Key Clinical Preventive Services for Adults.',
#      'Year': '2017'},
#     {'AuthorList': 'Kazi DS, Penko JM, Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2017-07-01T00:00:00',
#      'Featured': None,
#      'Publication': 'The Medical clinics of North America',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/162263093',
#      'PublicationMedlineTA': 'Med Clin North Am',
#      'PublicationSource': [{'PMID': '28577620',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28577620'}],
#      'PublicationTitle': 'Kazi DS, Penko JM, Bibbins-Domingo K. Statins for Primary Prevention of Cardiovascular Disease: Review of Evidence and Recommendations for Clinical Practice. Med Clin North Am. 2017 Jul; 101(4):689-699.',
#      'Title': 'Statins for Primary Prevention of Cardiovascular Disease: Review of Evidence and Recommendations for Clinical Practice.',
#      'Year': '2017'},
#     {'AuthorList': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#      'Claimed': True,
#      'Date': '2017-06-20T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/167120747',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28632874',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28632874'}],
#      'PublicationTitle': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW. Screening for Obesity in Children and Adolescents: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Jun 20; 317(23):2417-2426.',
#      'Title': 'Screening for Obesity in Children and Adolescents: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2017'},
#     {'AuthorList': 'Ben-Zeev A, Paluy Y, Milless KL, Goldstein EJ, Wallace L, Márquez-Magaña L, Bibbins-Domingo K, Estrada M',
#      'Claimed': True,
#      'Date': '2017-06-19T00:00:00',
#      'Featured': None,
#      'Publication': 'Education sciences',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/173610839',
#      'PublicationMedlineTA': 'Educ Sci (Basel)',
#      'PublicationSource': [{'PMID': '28835879',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28835879'}],
#      'PublicationTitle': "Ben-Zeev A, Paluy Y, Milless KL, Goldstein EJ, Wallace L, Márquez-Magaña L, Bibbins-Domingo K, Estrada M. 'Speaking Truth' Protects Underrepresented Minorities' Intellectual Performance and Safety in STEM. Educ Sci (Basel). 2017 Jun; 7(2).",
#      'Title': "'Speaking Truth' Protects Underrepresented Minorities' Intellectual Performance and Safety in STEM.",
#      'Year': '2017'},
#     {'AuthorList': 'Chen TK, Estrella MM, Vittinghoff E, Lin F, Gutierrez OM, Kramer H, Lewis CE, Kopp JB, Allen NB, Winkler CA, Bibbins-Domingo KB, Peralta CA',
#      'Claimed': True,
#      'Date': '2017-05-23T00:00:00',
#      'Featured': None,
#      'Publication': 'Kidney international',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/162263094',
#      'PublicationMedlineTA': 'Kidney Int',
#      'PublicationSource': [{'PMID': '28545715',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28545715'}],
#      'PublicationTitle': 'Chen TK, Estrella MM, Vittinghoff E, Lin F, Gutierrez OM, Kramer H, Lewis CE, Kopp JB, Allen NB, Winkler CA, Bibbins-Domingo KB, Peralta CA. APOL1 genetic variants are not associated with longitudinal blood pressure in young black adults. Kidney Int. 2017 Oct; 92(4):964-971.',
#      'Title': 'APOL1 genetic variants are not associated with longitudinal blood pressure in young black adults.',
#      'Year': '2017'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ',
#      'Claimed': True,
#      'Date': '2017-05-16T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/149329132',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28397958',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28397958'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ. The US Preventive Services Task Force 2017 Draft Recommendation Statement on Screening for Prostate Cancer: An Invitation to Review and Comment. JAMA. 2017 May 16; 317(19):1949-1950.',
#      'Title': 'The US Preventive Services Task Force 2017 Draft Recommendation Statement on Screening for Prostate Cancer: An Invitation to Review and Comment.',
#      'Year': '2017'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Siu AL, Tseng CW',
#      'Claimed': True,
#      'Date': '2017-05-09T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/162263095',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28492905',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28492905'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Siu AL, Tseng CW. Screening for Thyroid Cancer: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 May 09; 317(18):1882-1887.',
#      'Title': 'Screening for Thyroid Cancer: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2017'},
#     {'AuthorList': 'Kramer H, Colangelo L, Lewis CE, Jacobs DR, Pletcher M, Bibbins-Domingo K, Chang A, Siscovick D, Shlipak M, Peralta CA, Bansal N, Muntner P, Liu K',
#      'Claimed': True,
#      'Date': '2017-05-01T00:00:00',
#      'Featured': None,
#      'Publication': 'American journal of hypertension',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/146064005',
#      'PublicationMedlineTA': 'Am J Hypertens',
#      'PublicationSource': [{'PMID': '28338726',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28338726'}],
#      'PublicationTitle': 'Kramer H, Colangelo L, Lewis CE, Jacobs DR, Pletcher M, Bibbins-Domingo K, Chang A, Siscovick D, Shlipak M, Peralta CA, Bansal N, Muntner P, Liu K. Cumulative Exposure to Systolic Blood Pressure During Young Adulthood Through Midlife and the Urine Albumin-to-Creatinine Ratio at Midlife. Am J Hypertens. 2017 May 01; 30(5):502-509.',
#      'Title': 'Cumulative Exposure to Systolic Blood Pressure During Young Adulthood Through Midlife and the Urine Albumin-to-Creatinine Ratio at Midlife.',
#      'Year': '2017'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#      'Claimed': True,
#      'Date': '2017-04-25T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/152493885',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28444286',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28444286'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon MA, Tseng CW. Screening for Preeclampsia: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Apr 25; 317(16):1661-1667.',
#      'Title': 'Screening for Preeclampsia: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2017'},
#     {'AuthorList': 'Lunn MR, Obedin-Maliver J, Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2017-04-25T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/152493886',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28444268',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28444268'}],
#      'PublicationTitle': 'Lunn MR, Obedin-Maliver J, Bibbins-Domingo K. Estimating the Prevalence of Sexual Minority Adolescents. JAMA. 2017 04 25; 317(16):1691-1692.',
#      'Title': 'Estimating the Prevalence of Sexual Minority Adolescents.',
#      'Year': '2017'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Ebell M, Epling JW, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#      'Claimed': True,
#      'Date': '2017-03-28T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/146978504',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28350936',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28350936'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Ebell M, Epling JW, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW. Screening for Celiac Disease: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 03 28; 317(12):1252-1257.',
#      'Title': 'Screening for Celiac Disease: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2017'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon M, Siu AL, Tseng CW',
#      'Claimed': True,
#      'Date': '2017-03-07T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/143536187',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28267862',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28267862'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon M, Siu AL, Tseng CW. Screening for Gynecologic Conditions With Pelvic Examination: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 03 07; 317(9):947-953.',
#      'Title': 'Screening for Gynecologic Conditions With Pelvic Examination: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2017'},
#     {'AuthorList': 'Bibbins-Domingo K, Whitlock E, Wolff T, Ngo-Metzger Q, Phillips WR, Davidson KW, Krist AH, Lin JS, Mangione CM, Kurth AE, García FAR, Curry SJ, Grossman DC, Landefeld CS, Epling JW, Siu AL',
#      'Claimed': True,
#      'Date': '2017-03-07T00:00:00',
#      'Featured': None,
#      'Publication': 'Annals of internal medicine',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/143536188',
#      'PublicationMedlineTA': 'Ann Intern Med',
#      'PublicationSource': [{'PMID': '28265649',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28265649'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Whitlock E, Wolff T, Ngo-Metzger Q, Phillips WR, Davidson KW, Krist AH, Lin JS, Mangione CM, Kurth AE, García FAR, Curry SJ, Grossman DC, Landefeld CS, Epling JW, Siu AL. Developing Recommendations for Evidence-Based Clinical Preventive Services for Diverse Populations: Methods of the U.S. Preventive Services Task Force. Ann Intern Med. 2017 Apr 18; 166(8):565-571.',
#      'Title': 'Developing Recommendations for Evidence-Based Clinical Preventive Services for Diverse Populations: Methods of the U.S. Preventive Services Task Force.',
#      'Year': '2017'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW',
#      'Claimed': True,
#      'Date': '2017-01-24T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/140712977',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28118461',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28118461'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW. Screening for Obstructive Sleep Apnea in Adults: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Jan 24; 317(4):407-414.',
#      'Title': 'Screening for Obstructive Sleep Apnea in Adults: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2017'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW',
#      'Claimed': True,
#      'Date': '2017-01-10T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/137209449',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '28097362',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28097362'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW. Folic Acid Supplementation for the Prevention of Neural Tube Defects: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 01 10; 317(2):183-189.',
#      'Title': 'Folic Acid Supplementation for the Prevention of Neural Tube Defects: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2017'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW',
#      'Claimed': True,
#      'Date': '2016-12-20T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/133369762',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '27997659',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27997659'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW. Serologic Screening for Genital Herpes Infection: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 12 20; 316(23):2525-2530.',
#      'Title': 'Serologic Screening for Genital Herpes Infection: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2016'},
#     {'AuthorList': 'Grubbs V, Garcia F, Jue BL, Vittinghoff E, Ryder M, Lovett D, Carrillo J, Offenbacher S, Ganz P, Bibbins-Domingo K, Powe NR',
#      'Claimed': True,
#      'Date': '2016-12-20T00:00:00',
#      'Featured': None,
#      'Publication': 'Contemporary clinical trials',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/133369835',
#      'PublicationMedlineTA': 'Contemp Clin Trials',
#      'PublicationSource': [{'PMID': '28011387',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28011387'}],
#      'PublicationTitle': 'Grubbs V, Garcia F, Jue BL, Vittinghoff E, Ryder M, Lovett D, Carrillo J, Offenbacher S, Ganz P, Bibbins-Domingo K, Powe NR. The Kidney and Periodontal Disease (KAPD) study: A pilot randomized controlled trial testing the effect of non-surgical periodontal therapy on chronic kidney disease. Contemp Clin Trials. 2017 Feb; 53:143-150.',
#      'Title': 'The Kidney and Periodontal Disease (KAPD) study: A pilot randomized controlled trial testing the effect of non-surgical periodontal therapy on chronic kidney disease.',
#      'Year': '2016'},
#     {'AuthorList': 'Oh SS, Du R, Zeiger AM, McGarry ME, Hu D, Thakur N, Pino-Yanes M, Galanter JM, Eng C, Nishimura KK, Huntsman S, Farber HJ, Meade K, Avila P, Serebrisky D, Bibbins-Domingo K, Lenoir MA, Ford JG, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne SM, Sen S, Rodriguez-Santana JR, Williams K, Kumar R, Burchard EG',
#      'Claimed': True,
#      'Date': '2016-12-08T00:00:00',
#      'Featured': None,
#      'Publication': 'The Journal of asthma : official journal of the Association for the Care of Asthma',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/132444909',
#      'PublicationMedlineTA': 'J Asthma',
#      'PublicationSource': [{'PMID': '27929698',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27929698'}],
#      'PublicationTitle': 'Oh SS, Du R, Zeiger AM, McGarry ME, Hu D, Thakur N, Pino-Yanes M, Galanter JM, Eng C, Nishimura KK, Huntsman S, Farber HJ, Meade K, Avila P, Serebrisky D, Bibbins-Domingo K, Lenoir MA, Ford JG, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne SM, Sen S, Rodriguez-Santana JR, Williams K, Kumar R, Burchard EG. Breastfeeding associated with higher lung function in African American youths with asthma. J Asthma. 2016 Dec 08; 1-10.',
#      'Title': 'Breastfeeding associated with higher lung function in African American youths with asthma.',
#      'Year': '2016'},
#     {'AuthorList': 'Thakur N, Barcelo NE, Borrell LN, Singh S, Eng C, Davis A, Meade K, LeNoir MA, Avila PC, Farber HJ, Serebrisky D, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne S, Rodriguez-Santana JR, Sen S, Bibbins-Domingo K, Burchard EG',
#      'Claimed': True,
#      'Date': '2016-12-01T00:00:00',
#      'Featured': None,
#      'Publication': 'Chest',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/136107302',
#      'PublicationMedlineTA': 'Chest',
#      'PublicationSource': [{'PMID': '27916618',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27916618'}],
#      'PublicationTitle': 'Thakur N, Barcelo NE, Borrell LN, Singh S, Eng C, Davis A, Meade K, LeNoir MA, Avila PC, Farber HJ, Serebrisky D, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne S, Rodriguez-Santana JR, Sen S, Bibbins-Domingo K, Burchard EG. Perceived Discrimination Associated With Asthma and Related Outcomes in Minority Youth: The GALA II and SAGE II Studies. Chest. 2017 Apr; 151(4):804-812.',
#      'Title': 'Perceived Discrimination Associated With Asthma and Related Outcomes in Minority Youth: The GALA II and SAGE II Studies.',
#      'Year': '2016'},
#     {'AuthorList': 'Zaitlen N, Huntsman S, Hu D, Spear M, Eng C, Oh SS, White MJ, Mak A, Davis A, Meade K, Brigino-Buenaventura E, LeNoir MA, Bibbins-Domingo K, Burchard EG, Halperin E',
#      'Claimed': True,
#      'Date': '2016-11-22T00:00:00',
#      'Featured': None,
#      'Publication': 'Genetics',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/129242115',
#      'PublicationMedlineTA': 'Genetics',
#      'PublicationSource': [{'PMID': '27879348',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27879348'}],
#      'PublicationTitle': 'Zaitlen N, Huntsman S, Hu D, Spear M, Eng C, Oh SS, White MJ, Mak A, Davis A, Meade K, Brigino-Buenaventura E, LeNoir MA, Bibbins-Domingo K, Burchard EG, Halperin E. The Effects of Migration and Assortative Mating on Admixture Linkage Disequilibrium. Genetics. 2017 Jan; 205(1):375-383.',
#      'Title': 'The Effects of Migration and Assortative Mating on Admixture Linkage Disequilibrium.',
#      'Year': '2016'},
#     {'AuthorList': 'Kazi DS, Moran AE, Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2016-11-22T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/130513267',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '27893125',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27893125'}],
#      'PublicationTitle': 'Kazi DS, Moran AE, Bibbins-Domingo K. Cost-effectiveness of PCSK9 Inhibitor Therapy-Reply. JAMA. 2016 Nov 22; 316(20):2152.',
#      'Title': 'Cost-effectiveness of PCSK9 Inhibitor Therapy-Reply.',
#      'Year': '2016'},
#     {'AuthorList': 'Konfino J, Fernandez A, Penko J, Mason A, Martinez E, Coxson P, Heller D, Moran A, Bibbins-Domingo K, Pérez-Stable EJ, Mejía R',
#      'Claimed': True,
#      'Date': '2016-11-16T00:00:00',
#      'Featured': None,
#      'Publication': 'Journal of general internal medicine',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/128265828',
#      'PublicationMedlineTA': 'J Gen Intern Med',
#      'PublicationSource': [{'PMID': '27853916',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27853916'}],
#      'PublicationTitle': 'Konfino J, Fernandez A, Penko J, Mason A, Martinez E, Coxson P, Heller D, Moran A, Bibbins-Domingo K, Pérez-Stable EJ, Mejía R. Comparing Strategies for Lipid Lowering in Argentina: An Analysis from the CVD Policy Model-Argentina. J Gen Intern Med. 2017 May; 32(5):524-533.',
#      'Title': 'Comparing Strategies for Lipid Lowering in Argentina: An Analysis from the CVD Policy Model-Argentina.',
#      'Year': '2016'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Gillman MW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, LeFevre ML, Mangione CM, Phillips WR, Owens DK, Phipps MG, Pignone MP',
#      'Claimed': True,
#      'Date': '2016-11-15T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/127816615',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '27838723',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27838723'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Gillman MW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, LeFevre ML, Mangione CM, Phillips WR, Owens DK, Phipps MG, Pignone MP. Statin Use for the Primary Prevention of Cardiovascular Disease in Adults: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 Nov 15; 316(19):1997-2007.',
#      'Title': 'Statin Use for the Primary Prevention of Cardiovascular Disease in Adults: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2016'},
#     {'AuthorList': 'Georgiopoulou VV, Kalogeropoulos AP, Chowdhury R, Binongo JN, Bibbins-Domingo K, Rodondi N, Simonsick EM, Harris T, Newman AB, Kritchevsky SB, Butler J',
#      'Claimed': True,
#      'Date': '2016-11-14T00:00:00',
#      'Featured': None,
#      'Publication': 'American journal of preventive medicine',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/128265852',
#      'PublicationMedlineTA': 'Am J Prev Med',
#      'PublicationSource': [{'PMID': '27856115',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27856115'}],
#      'PublicationTitle': 'Georgiopoulou VV, Kalogeropoulos AP, Chowdhury R, Binongo JN, Bibbins-Domingo K, Rodondi N, Simonsick EM, Harris T, Newman AB, Kritchevsky SB, Butler J. Exercise Capacity, Heart Failure Risk, and Mortality in Older Adults: The Health ABC Study. Am J Prev Med. 2017 Feb; 52(2):144-153.',
#      'Title': 'Exercise Capacity, Heart Failure Risk, and Mortality in Older Adults: The Health ABC Study.',
#      'Year': '2016'},
#     {'AuthorList': 'Sánchez-Romero LM, Penko J, Coxson PG, Fernández A, Mason A, Moran AE, Ávila-Burgos L, Odden M, Barquera S, Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2016-11-01T00:00:00',
#      'Featured': None,
#      'Publication': 'PLoS medicine',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/125550651',
#      'PublicationMedlineTA': 'PLoS Med',
#      'PublicationSource': [{'PMID': '27802278',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27802278'}],
#      'PublicationTitle': "Sánchez-Romero LM, Penko J, Coxson PG, Fernández A, Mason A, Moran AE, Ávila-Burgos L, Odden M, Barquera S, Bibbins-Domingo K. Projected Impact of Mexico's Sugar-Sweetened Beverage Tax Policy on Diabetes and Cardiovascular Disease: A Modeling Study. PLoS Med. 2016 Nov; 13(11):e1002158.",
#      'Title': "Projected Impact of Mexico's Sugar-Sweetened Beverage Tax Policy on Diabetes and Cardiovascular Disease: A Modeling Study.",
#      'Year': '2016'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP',
#      'Claimed': True,
#      'Date': '2016-10-25T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/125550647',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '27784102',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27784102'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP. Primary Care Interventions to Support Breastfeeding: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 10 25; 316(16):1688-1693.',
#      'Title': 'Primary Care Interventions to Support Breastfeeding: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2016'},
#     {'AuthorList': 'Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2016-10-25T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/125550648',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '27784091',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27784091'}],
#      'PublicationTitle': 'Bibbins-Domingo K. Colorectal Cancer Screening Recommendations-Reply. JAMA. 2016 Oct 25; 316(16):1717.',
#      'Title': 'Colorectal Cancer Screening Recommendations-Reply.',
#      'Year': '2016'},
#     {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Bauman L, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP',
#      'Claimed': True,
#      'Date': '2016-09-06T00:00:00',
#      'Featured': None,
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/119164730',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '27599331',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27599331'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Bauman L, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP. Screening for Latent Tuberculosis Infection in Adults: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 Sep 06; 316(9):962-9.',
#      'Title': 'Screening for Latent Tuberculosis Infection in Adults: US Preventive Services Task Force Recommendation Statement.',
#      'Year': '2016'},
#     {'AuthorList': 'Kazi DS, Moran AE, Coxson PG, Penko J, Ollendorf DA, Pearson SD, Tice JA, Guzman D, Bibbins-Domingo K',
#      'Claimed': True,
#      'Date': '2016-08-16T00:00:00',
#      'Featured': '1',
#      'Publication': 'JAMA',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/116246030',
#      'PublicationMedlineTA': 'JAMA',
#      'PublicationSource': [{'PMID': '27533159',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27533159'}],
# ...
#      'Featured': None,
#      'Publication': 'Archives of internal medicine',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/324786',
#      'PublicationMedlineTA': 'Arch Intern Med',
#      'PublicationSource': [{'PMID': '16832005',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/16832005'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Chertow GM, Fried LF, Odden MC, Newman AB, Kritchevsky SB, Harris TB, Satterfield S, Cummings SR, Shlipak MG. Renal function and heart failure risk in older black and white individuals: the Health, Aging, and Body Composition Study. Arch Intern Med. 2006 Jul 10; 166(13):1396-402.',
#      'Title': 'Renal function and heart failure risk in older black and white individuals: the Health, Aging, and Body Composition Study.',
#      'Year': '2006'},
#     {'AuthorList': 'Piette JD, Bibbins-Domingo K, Schillinger D',
#      'Claimed': True,
#      'Date': '2005-01-21T00:00:00',
#      'Featured': None,
#      'Publication': 'Patient education and counseling',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/323448',
#      'PublicationMedlineTA': 'Patient Educ Couns',
#      'PublicationSource': [{'PMID': '16332469',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/16332469'}],
#      'PublicationTitle': "Piette JD, Bibbins-Domingo K, Schillinger D. Health care discrimination, processes of care, and diabetes patients' health status. Patient Educ Couns. 2006 Jan; 60(1):41-8.",
#      'Title': "Health care discrimination, processes of care, and diabetes patients' health status.",
#      'Year': '2005'},
#     {'AuthorList': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG',
#      'Claimed': True,
#      'Date': '2005-01-15T00:00:00',
#      'Featured': None,
#      'Publication': 'The American journal of cardiology',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/321446',
#      'PublicationMedlineTA': 'Am J Cardiol',
#      'PublicationSource': [{'PMID': '15642574',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15642574'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG. Effect of hormone therapy on mortality rates among women with heart failure and coronary artery disease. Am J Cardiol. 2005 Jan 15; 95(2):289-91.',
#      'Title': 'Effect of hormone therapy on mortality rates among women with heart failure and coronary artery disease.',
#      'Year': '2005'},
#     {'AuthorList': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Grady D, Shlipak MG',
#      'Claimed': True,
#      'Date': '2004-10-19T00:00:00',
#      'Featured': None,
#      'Publication': 'Journal of the American College of Cardiology',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/321003',
#      'PublicationMedlineTA': 'J Am Coll Cardiol',
#      'PublicationSource': [{'PMID': '15489091',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15489091'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Grady D, Shlipak MG. Renal insufficiency as an independent predictor of mortality among women with heart failure. J Am Coll Cardiol. 2004 Oct 19; 44(8):1593-600.',
#      'Title': 'Renal insufficiency as an independent predictor of mortality among women with heart failure.',
#      'Year': '2004'},
#     {'AuthorList': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG',
#      'Claimed': True,
#      'Date': '2004-09-07T00:00:00',
#      'Featured': None,
#      'Publication': 'Circulation',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/272249',
#      'PublicationMedlineTA': 'Circulation',
#      'PublicationSource': [{'PMID': '15353499',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15353499'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG. Predictors of heart failure among women with coronary disease. Circulation. 2004 Sep 14; 110(11):1424-30.',
#      'Title': 'Predictors of heart failure among women with coronary disease.',
#      'Year': '2004'},
#     {'AuthorList': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA',
#      'Claimed': True,
#      'Date': '2004-04-15T00:00:00',
#      'Featured': None,
#      'Publication': 'The American journal of medicine',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/319953',
#      'PublicationMedlineTA': 'Am J Med',
#      'PublicationSource': [{'PMID': '15063811',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15063811'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA. Is B-type natriuretic peptide a useful screening test for systolic or diastolic dysfunction in patients with coronary disease? Data from the Heart and Soul Study. Am J Med. 2004 Apr 15; 116(8):509-16.',
#      'Title': 'Is B-type natriuretic peptide a useful screening test for systolic or diastolic dysfunction in patients with coronary disease? Data from the Heart and Soul Study.',
#      'Year': '2004'},
#     {'AuthorList': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA',
#      'Claimed': True,
#      'Date': '2003-12-08T00:00:00',
#      'Featured': None,
#      'Publication': 'Circulation',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/261298',
#      'PublicationMedlineTA': 'Circulation',
#      'PublicationSource': [{'PMID': '14662720',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/14662720'}],
#      'PublicationTitle': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA. B-type natriuretic peptide and ischemia in patients with stable coronary disease: data from the Heart and Soul study. Circulation. 2003 Dec 16; 108(24):2987-92.',
#      'Title': 'B-type natriuretic peptide and ischemia in patients with stable coronary disease: data from the Heart and Soul study.',
#      'Year': '2003'},
#     {'AuthorList': 'Schillinger D, Bibbins-Domingo K, Vranizan K, Bacchetti P, Luce JM, Bindman AB',
#      'Claimed': True,
#      'Date': '2000-05-01T00:00:00',
#      'Featured': None,
#      'Publication': 'Journal of general internal medicine',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/313775',
#      'PublicationMedlineTA': 'J Gen Intern Med',
#      'PublicationSource': [{'PMID': '10840268',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/10840268'}],
#      'PublicationTitle': 'Schillinger D, Bibbins-Domingo K, Vranizan K, Bacchetti P, Luce JM, Bindman AB. Effects of primary care coordination on public hospital patients. J Gen Intern Med. 2000 May; 15(5):329-36.',
#      'Title': 'Effects of primary care coordination on public hospital patients.',
#      'Year': '2000'},
#     {'AuthorList': 'Boeuf H, Murphy J, Bibbins KB, Varmus HE',
#      'Claimed': True,
#      'Date': '1995-02-02T00:00:00',
#      'Featured': None,
#      'Publication': 'Oncogene',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/241654',
#      'PublicationMedlineTA': 'Oncogene',
#      'PublicationSource': [{'PMID': '7531318',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/7531318'}],
#      'PublicationTitle': 'Boeuf H, Murphy J, Bibbins KB, Varmus HE. Binding in vitro of phosphotyrosine-containing proteins to pp60c-src SH2 domain does not correlate with CEF transformation. Oncogene. 1995 Feb 02; 10(3):433-8.',
#      'Title': 'Binding in vitro of phosphotyrosine-containing proteins to pp60c-src SH2 domain does not correlate with CEF transformation.',
#      'Year': '1995'},
#     {'AuthorList': 'Kaplan KB, Bibbins KB, Swedlow JR, Arnaud M, Morgan DO, Varmus HE',
#      'Claimed': True,
#      'Date': '1994-10-17T00:00:00',
#      'Featured': None,
#      'Publication': 'The EMBO journal',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/234511',
#      'PublicationMedlineTA': 'EMBO J',
#      'PublicationSource': [{'PMID': '7525268',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/7525268'}],
#      'PublicationTitle': 'Kaplan KB, Bibbins KB, Swedlow JR, Arnaud M, Morgan DO, Varmus HE. Association of the amino-terminal half of c-Src with focal adhesions alters their properties and is regulated by phosphorylation of tyrosine 527. EMBO J. 1994 Oct 17; 13(20):4745-56.',
#      'Title': 'Association of the amino-terminal half of c-Src with focal adhesions alters their properties and is regulated by phosphorylation of tyrosine 527.',
#      'Year': '1994'},
#     {'AuthorList': 'Bibbins KB, Boeuf H, Varmus HE',
#      'Claimed': True,
#      'Date': '1993-12-01T00:00:00',
#      'Featured': None,
#      'Publication': 'Molecular and cellular biology',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/234440',
#      'PublicationMedlineTA': 'Mol Cell Biol',
#      'PublicationSource': [{'PMID': '7504171',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/7504171'}],
#      'PublicationTitle': 'Bibbins KB, Boeuf H, Varmus HE. Binding of the Src SH2 domain to phosphopeptides is determined by residues in both the SH2 domain and the phosphopeptides. Mol Cell Biol. 1993 Dec; 13(12):7278-87.',
#      'Title': 'Binding of the Src SH2 domain to phosphopeptides is determined by residues in both the SH2 domain and the phosphopeptides.',
#      'Year': '1993'},
#     {'AuthorList': 'Bibbins KB, Tsai JY, Schimenti J, Sarvetnick N, Zoghbi HY, Goodfellow P, Silver LM',
#      'Claimed': True,
#      'Date': '1989-07-01T00:00:00',
#      'Featured': None,
#      'Publication': 'Genomics',
#      'PublicationCategory': None,
#      'PublicationID': 'http://profiles.ucsf.edu/profile/223263',
#      'PublicationMedlineTA': 'Genomics',
#      'PublicationSource': [{'PMID': '2767684',
#        'PublicationSourceName': 'PubMed',
#        'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/2767684'}],
#      'PublicationTitle': 'Bibbins KB, Tsai JY, Schimenti J, Sarvetnick N, Zoghbi HY, Goodfellow P, Silver LM. Human homologs of two testes-expressed loci on mouse chromosome 17 map to opposite arms of chromosome 6. Genomics. 1989 Jul; 5(1):139-43.',
#      'Title': 'Human homologs of two testes-expressed loci on mouse chromosome 17 map to opposite arms of chromosome 6.',
#      'Year': '1989'}],
#    'ResearchActivitiesAndFunding': [{'EndDate': '2022-08-31',
#      'Role': 'Principal Investigator',
#      'Sponsor': 'NIH/NHLBI',
#      'SponsorAwardID': 'K12HL138046',
#      'StartDate': '2017-09-01',
#      'Title': 'UCSF Career Development Program in Implementation Research in Heart and Lung Diseases'},
#     {'EndDate': '2021-05-31',
#      'Role': 'Principal Investigator',
#      'Sponsor': 'NIH/NCATS',
#      'SponsorAwardID': 'TL1TR001871',
#      'StartDate': '2016-07-18',
#      'Title': 'NRSA Training Core'},
#     {'EndDate': '2021-05-31',
#      'Role': 'Co-Principal Investigator',
#      'Sponsor': 'NIH/NCATS',
#      'SponsorAwardID': 'KL2TR001870',
#      'StartDate': '2016-07-18',
#      'Title': 'Institutional Career Development Core'},
#     {'EndDate': '2019-07-31',
#      'Role': 'Principal Investigator',
#      'Sponsor': 'NIH/NIDDK',
#      'SponsorAwardID': 'K24DK103992',
#      'StartDate': '2014-09-20',
#      'Title': 'Hypertension Management in Minority and Low-income Populations'},
#     {'EndDate': '2019-06-30',
#      'Role': 'Co-Principal Investigator',
#      'Sponsor': 'NIH/NIMHD',
#      'SponsorAwardID': 'TL4MD009638',
#      'StartDate': '2014-09-26',
#      'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#     {'EndDate': '2019-06-30',
#      'Role': 'Co-Principal Investigator',
#      'Sponsor': 'NIH/NIGMS',
#      'SponsorAwardID': 'UL1GM118985',
#      'StartDate': '2014-09-26',
#      'Title': 'SF BUILD: Enabling Students to Represnt in Science'},
#     {'EndDate': '2019-06-30',
#      'Role': 'Co-Principal Investigator',
#      'Sponsor': 'NIH/NIGMS',
#      'SponsorAwardID': 'RL5GM118984',
#      'StartDate': '2014-09-26',
#      'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#     {'EndDate': '2019-06-30',
#      'Role': 'Co-Principal Investigator',
#      'Sponsor': 'NIH/NIMHD',
#      'SponsorAwardID': 'RL5MD009599',
#      'StartDate': '2014-09-26',
#      'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#     {'EndDate': '2019-06-30',
#      'Role': 'Co-Principal Investigator',
#      'Sponsor': 'NIH/NIGMS',
#      'SponsorAwardID': 'TL4GM118986',
#      'StartDate': '2014-09-26',
#      'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#     {'EndDate': '2019-06-30',
#      'Role': 'Co-Principal Investigator',
#      'Sponsor': 'NIH/NIMHD',
#      'SponsorAwardID': 'UL1MD009608',
#      'StartDate': '2014-09-26',
#      'Title': 'SF BUILD: Enabling Students to Represnt in Science'},
#     {'EndDate': '2018-06-30',
#      'Role': 'Co-Principal Investigator',
#      'Sponsor': 'NIH',
#      'SponsorAwardID': 'OT2OD025276',
#      'StartDate': '2017-07-23',
#      'Title': 'All of Us Research Program National Sexual and Gender Minority Engagement Network'},
#     {'EndDate': '2018-05-31',
#      'Role': 'Principal Investigator',
#      'Sponsor': 'NIH/NHLBI',
#      'SponsorAwardID': 'R25HL126146',
#      'StartDate': '2014-09-15',
#      'Title': 'UCSF Research in Implementation Sciences for Equity (RISE)'},
#     {'EndDate': '2017-08-31',
#      'Role': 'Co-Principal Investigator',
#      'Sponsor': 'NIH/NINDS',
#      'SponsorAwardID': 'U54NS081760',
#      'StartDate': '2012-09-30',
#      'Title': 'The Discovering Healthcare Innovations to Address Disparties in Stroke (DIADS) pr'},
#     {'EndDate': '2017-02-28',
#      'Role': 'Principal Investigator',
#      'Sponsor': 'NIH/NIMHD',
#      'SponsorAwardID': 'P60MD006902',
#      'StartDate': '2012-08-27',
#      'Title': 'Addressing disparities in chronic disease with a teen and young adult focus'},
#     {'EndDate': '2016-02-29',
#      'Role': 'Principal Investigator',
#      'Sponsor': 'NIH/FIC',
#      'SponsorAwardID': 'R03TW009061',
#      'StartDate': '2013-03-20',
#      'Title': 'Enhancing Mexican Capacity for CVD Policy Research'},
#     {'EndDate': '2012-07-31',
#      'Role': 'Principal Investigator',
#      'Sponsor': 'NIH/NIDDK',
#      'SponsorAwardID': 'R01DK078124',
#      'StartDate': '2008-08-01',
#      'Title': 'Chronic Kidney Disease and Cardiovascular Risk in Black and White Young Adults'}],
#    'School': 'UCSF School of Medicine',
#    'SlideShare_beta': [],
#    'Title': 'Professor',
#    'Titles': ['Professor'],
#    'Twitter_beta': ['ucsfcvp'],
#    'Videos': [{'label': 'Mission in a Minute',
#      'url': 'https://www.youtube.com/watch?v=DxLJwwvcg-o&index=1&list=PLVLbDUiGesPyQqgEEsceWk4-FzSmMeI_d'},
#     {'label': 'A Life in Medicine: People Shaping Healthcare Today',
#      'url': 'https://youtu.be/lzivJjGwPdU'}],
#    'WebLinks_beta': [{'Label': 'UCSF Center for Vulnerable Populations at San Francisco General Hospital',
#      'URL': 'http://cvp.ucsf.edu/'},
#     {'Label': 'UCSF CTSI K Scholars Program',
#      'URL': 'http://ctsi.ucsf.edu/our-work/k-scholars-program'},
#     {'Label': 'Sugar Science',
#      'URL': 'http://sugarscience.org/sugarscientist-team/#.VGFBsvTF-wA'},
#     {'Label': 'Bring It Down Stroke Study',
#      'URL': 'http://www.bringitdownstudy.org/'}]}],
#  'api_notes': 'To maximize performance, we are providing recently-cached data. This data was cached on Mon Nov  6 08:14:59 2017'}

# %% [markdown]
# We can check the type to verify that the data we retrieved is now stored in python as a dictionary

# %%
type(data)
# Out:
# dict

# %% [markdown]
# You can investigate the keys by visually inspecting the document, but JSON responses can be long, nested, and complex.  An easier way is to list the keys.

# %%
data.keys()
# Out:
# dict_keys(['Profiles', 'api_notes'])

# %% [markdown]
# Let's take a look at the information data in the 'Profiles' section of this dictionary.

# %%
profiles = data['Profiles']

# %% [markdown]
# As before, a dictionary can contain either primitives or objects, including other data structures such as lists or other dictionaries

# %%
profiles
# Out:
# [{'Address': {'Address1': '550 16th. Street',
#    'Address2': 'San Francisco, CA 94158',
#    'Address3': None,
#    'Address4': None,
#    'Fax': '415-514-8150',
#    'Latitude': '37.755637',
#    'Longitude': '-122.405102',
#    'Telephone': '415-502-4106'},
#   'AwardOrHonors': [{'AwardConferredBy': None,
#     'AwardEndDate': None,
#     'AwardLabel': 'Association of American Physicians',
#     'AwardStartDate': '2017',
#     'Summary': 'Association of American Physicians, 2017'},
#    {'AwardConferredBy': None,
#     'AwardEndDate': None,
#     'AwardLabel': 'National Academy of Medicine',
#     'AwardStartDate': '2015',
#     'Summary': 'National Academy of Medicine, 2015'},
#    {'AwardConferredBy': None,
#     'AwardEndDate': None,
#     'AwardLabel': 'Mid-career Research Mentor Award - Society of General Internal Medicine',
#     'AwardStartDate': '2014',
#     'Summary': 'Mid-career Research Mentor Award - Society of General Internal Medicine, 2014'},
#    {'AwardConferredBy': None,
#     'AwardEndDate': None,
#     'AwardLabel': 'Lee Goldman, MD Endowed Chair in Medicine',
#     'AwardStartDate': '2012',
#     'Summary': 'Lee Goldman, MD Endowed Chair in Medicine, 2012'},
#    {'AwardConferredBy': None,
#     'AwardEndDate': None,
#     'AwardLabel': 'American Society for Clinical Investigation',
#     'AwardStartDate': '2010',
#     'Summary': 'American Society for Clinical Investigation, 2010'}],
#   'Department': 'Epidemiology & Biostatistics',
#   'Education_Training': [{'degree': 'MAS',
#     'department_or_school': 'Epidemiology and Biostatistics',
#     'end_date': '2004',
#     'organization': 'University of California, San Francisco',
#     'start_date': ''},
#    {'degree': 'Residency',
#     'department_or_school': 'Medicine',
#     'end_date': '2001',
#     'organization': 'University of California, San Francisco',
#     'start_date': ''},
#    {'degree': 'MD',
#     'department_or_school': 'Medicine',
#     'end_date': '1999',
#     'organization': 'University of California, San Francisco',
#     'start_date': ''},
#    {'degree': 'PhD',
#     'department_or_school': 'Graduate Division (Biochemistry)',
#     'end_date': '1994',
#     'organization': 'University of California, San Francisco',
#     'start_date': ''},
#    {'degree': 'AB',
#     'department_or_school': 'Molecular Biology',
#     'end_date': '1987',
#     'organization': 'Princeton University',
#     'start_date': ''}],
#   'Email': 'kirsten.bibbins-domingo@ucsf.edu',
#   'FirstName': 'Kirsten',
#   'FreetextKeywords': ['Chronic disease prevention',
#    'Cardiovascular disease',
#    'Health of young adults',
#    'Kidney disease',
#    'Health disparities'],
#   'GlobalHealth_beta': {'Countries': ['Argentina',
#     'Chile',
#     'China',
#     'Mexico',
#     'Puerto Rico',
#     'United States']},
#   'Keywords': ['Primary Prevention',
#    'Cardiovascular Diseases',
#    'Hypertension',
#    'Advisory Committees',
#    'Mass Screening'],
#   'LastName': 'Bibbins-Domingo',
#   'MediaLinks_beta': [{'Date': '2017-08-22',
#     'Label': 'UCSF to Lead Gathering of Important Health Information for Sexual, Gender Minorities',
#     'URL': 'https://www.ucsf.edu/news/2017/08/408116/ucsf-lead-gathering-important-health-information-sexual-gender-minorities'},
#    {'Date': '2017-07-21',
#     'Label': 'Kirsten Bibbins-Domingo, PhD, MD, MAS Appointed as Chair of Epidemiology and Biostatistics and Inaugural Vice Dean for Population Health and Health Equity',
#     'URL': 'https://medschool.ucsf.edu/kirsten-bibbins-domingo-phd-md-mas-appointed-chair-epidemiology-and-biostatistics-and-inaugural-vice'},
#    {'Date': '2017-04-17',
#     'Label': 'KQED Forum with Michael Krasny',
#     'URL': 'https://ww2.kqed.org/forum/2017/04/14/new-guidelines-let-patients-opt-in-to-controversial-prostate-cancer-screening/'},
#    {'Date': '2017-02-07',
#     'Label': 'In Decade Since Founding, UCSF’s Center for Vulnerable Populations Has Innovated Research, Care',
#     'URL': 'https://www.ucsf.edu/news/2017/02/405736/decade-founding-ucsfs-center-vulnerable-populations-has-innovated-research-care'},
#    {'Date': '2016-11-01',
#     'Label': 'Do soda taxes work? Experts look to Mexico',
#     'URL': 'http://www.cnn.com/2016/11/01/health/soda-tax-benefits-mexico/index.html'},
#    {'Date': '2016-09-15',
#     'Label': 'In a first, aspirin is recommended to fight a form of cancer',
#     'URL': 'http://well.blogs.nytimes.com/2015/09/14/in-a-first-aspirin-is-recommended-to-fight-a-form-of-cancer/?_r=0'},
#    {'Date': '2016-08-26',
#     'Label': 'Cost of New Cholesterol Drug Unsustainable',
#     'URL': 'https://www.ucsf.edu/news/2016/08/403891/cost-new-cholesterol-drugs-unsustainable-says-study'},
#    {'Date': '2015-06-25',
#     'Label': 'UCSF Researchers Launch Landmark Study of LGBTQ Community Health',
#     'URL': 'https://www.ucsf.edu/news/2015/06/130631/ucsf-researchers-launch-landmark-study-lgbtq-community-health'},
#    {'Date': '2015-04-29',
#     'Label': 'New breast cancer screening guidelines explained',
#     'URL': 'http://www.washingtonpost.com/news/to-your-health/wp/2015/04/29/new-breast-cancer-screening-guidelines-explained/'},
#    {'Date': '2015-04-20',
#     'Label': 'Statin Use in Elderly Would Prevent Disease But Could Carry Considerable Side Effects',
#     'URL': 'http://www.ucsf.edu/news/2015/04/125236/statin-use-elderly-would-prevent-disease-could-carry-considerable-side-effects'},
#    {'Date': '2014-11-10',
#     'Label': 'SFSU and UCSF Awarded $17 Million to Increase Diversity in the Biomedical',
#     'URL': 'http://ctsi.ucsf.edu/news/about-ctsi/sfsu-and-ucsf-awarded-17-million-increase-diversity-biomedical-workforce'},
#    {'Date': '2014-10-23',
#     'Label': 'S.F. State receives $17 million grant to help minorities',
#     'URL': 'http://www.sfgate.com/education/article/S-F-State-receives-17-million-grant-to-help-5843661.php'},
#    {'Date': '2014-01-05',
#     'Label': "Bay Area's People to Watch in 2014",
#     'URL': 'http://www.sfgate.com/bayarea/article/Bay-Area-s-People-to-Watch-in-2014-5114765.php'},
#    {'Date': '2013-06-04',
#     'Label': "Q&A With Director of UCSF's K Scholars Program",
#     'URL': 'http://www.ucsf.edu/news/2013/06/106411/qa-co-director-ucsf-k-scholars-program'},
#    {'Date': '2013-02-11',
#     'Label': 'Reducing Sodium in American Diet Would Save Hundreds of Thousands of Lives',
#     'URL': 'http://www.ucsf.edu/news/2013/02/13516/reducing-sodium-american-diet-would-save-hundreds-thousands-lives'},
#    {'Date': '2012-09-04',
#     'Label': 'Undergraduates Get Hands-On Experience with Clinical Research',
#     'URL': 'http://www.ucsf.edu/news/2012/09/12662/undergraduates-get-hands-experience-clinical-research'},
#    {'Date': '2012-01-09',
#     'Label': 'How Many Lives Could a Soda Tax Save?',
#     'URL': 'http://www.ucsf.edu/news/2012/01/11267/how-many-lives-could-soda-tax-save'}],
#   'NIHGrants_beta': [{'NIHFiscalYear': '2018',
#     'NIHProjectNumber': 'OT2OD025276',
#     'Title': 'All of Us Research Program National Sexual and Gender Minority Engagement Network',
#     'api_notes': 'Deprecated, use ResearchActivitiesAndFunding instead. The fiscal year may be off.'}],
#   'Name': 'Kirsten Bibbins-Domingo, MD, PhD, MAS',
#   'Narrative': 'Kirsten Bibbins-Domingo, PhD, MD, MAS is the Lee Goldman, MD Endowed Chair in Medicine and Professor of Epidemiology and Biostatistics and Medicine. She is the Vice Dean for Population Health and Health Equity in the UCSF School of Medicine, and she directs the UCSF Center for Vulnerable Populations at Zuckerberg San Francisco General Hospital, a research center focused on discovery, implementation, policy, advocacy, and community engagement for communities at risk for poor health and inadequate healthcare.  She is the Director of the CTSI Clinical and Translational Science Training (CTST) Programs.  A general internist at Zuckerberg San Francisco General Hospital, Dr. Bibbins-Domingo has expertise in cardiovascular disease, diabetes, and chronic kidney disease with a particular interest in the development of chronic disease in young adults.  Her work focuses on racial, ethnic and income differences in manifestations of chronic disease and effective clinical, public health, and policy interventions aimed at prevention.  She leads the UCSF computer simulation modeling group using the Cardiovascular Disease Policy Model.  Dr. Bibbins-Domingo is the PI or joint PI of three collaborative center grants from the NIH: the NIMHD P60 Center for Health And Risk in Minority youth and adults (CHARM) addressing disparities in chronic disease in youth and young adults, Bring It Down  an NINDS U54 research center addressing stroke prevention and stroke disparities in collaboration with Kaiser Permanente Northern California, and BUILD  a NIGMS U54 infrastructure and training grant with San Francisco State University.  She has been a member of the US Preventive Services Task Force since 2010 and is the Immediate Past Chair. She is a member of the American Society for Clinical Investigation, the National Academy of Medicine, and the Association of American Physicians.',
#   'PhotoURL': 'http://profiles.ucsf.edu/profile/Modules/CustomViewPersonGeneralInfo/PhotoHandler.ashx?NodeID=370012',
#   'ProfilesURL': 'http://profiles.ucsf.edu/kirsten.bibbins-domingo',
#   'PublicationCount': '218',
#   'Publications': [{'AuthorList': 'Hiatt RA, Handley MA, Ling PM, Burchard E, Thakur N, Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2017-09-01T00:00:00',
#     'Featured': None,
#     'Publication': 'American journal of preventive medicine',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/173083677',
#     'PublicationMedlineTA': 'Am J Prev Med',
#     'PublicationSource': [{'PMID': '28818252',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28818252'}],
#     'PublicationTitle': 'Hiatt RA, Handley MA, Ling PM, Burchard E, Thakur N, Bibbins-Domingo K. Origins of Cancer Disparities in Young Adults: Logic Models to Guide Research. Am J Prev Med. 2017 Sep; 53(3S1):S95-S102.',
#     'Title': 'Origins of Cancer Disparities in Young Adults: Logic Models to Guide Research.',
#     'Year': '2017'},
#    {'AuthorList': 'Ling PM, Holmes LM, Jordan JW, Lisha NE, Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2017-09-01T00:00:00',
#     'Featured': None,
#     'Publication': 'American journal of preventive medicine',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/173083678',
#     'PublicationMedlineTA': 'Am J Prev Med',
#     'PublicationSource': [{'PMID': '28818250',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28818250'}],
#     'PublicationTitle': 'Ling PM, Holmes LM, Jordan JW, Lisha NE, Bibbins-Domingo K. Bars, Nightclubs, and Cancer Prevention: New Approaches to Reduce Young Adult Cigarette Smoking. Am J Prev Med. 2017 Sep; 53(3S1):S78-S85.',
#     'Title': 'Bars, Nightclubs, and Cancer Prevention: New Approaches to Reduce Young Adult Cigarette Smoking.',
#     'Year': '2017'},
#    {'AuthorList': 'Schillinger D, Ling PM, Fine S, Boyer CB, Rogers E, Vargas RA, Bibbins-Domingo K, Chou WS',
#     'Claimed': True,
#     'Date': '2017-09-01T00:00:00',
#     'Featured': None,
#     'Publication': 'American journal of preventive medicine',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/173083679',
#     'PublicationMedlineTA': 'Am J Prev Med',
#     'PublicationSource': [{'PMID': '28818240',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28818240'}],
#     'PublicationTitle': 'Schillinger D, Ling PM, Fine S, Boyer CB, Rogers E, Vargas RA, Bibbins-Domingo K, Chou WS. Reducing Cancer and Cancer Disparities: Lessons From a Youth-Generated Diabetes Prevention Campaign. Am J Prev Med. 2017 Sep; 53(3S1):S103-S113.',
#     'Title': 'Reducing Cancer and Cancer Disparities: Lessons From a Youth-Generated Diabetes Prevention Campaign.',
#     'Year': '2017'},
#    {'AuthorList': 'Ishida JH, Auer R, Vittinghoff E, Pletcher MJ, Reis JP, Sidney S, Johansen KL, Bibbins-Domingo K, Peralta CA, Shlipak MG',
#     'Claimed': True,
#     'Date': '2017-08-24T00:00:00',
#     'Featured': None,
#     'Publication': 'Clinical journal of the American Society of Nephrology : CJASN',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/173610838',
#     'PublicationMedlineTA': 'Clin J Am Soc Nephrol',
#     'PublicationSource': [{'PMID': '28838990',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28838990'}],
#     'PublicationTitle': 'Ishida JH, Auer R, Vittinghoff E, Pletcher MJ, Reis JP, Sidney S, Johansen KL, Bibbins-Domingo K, Peralta CA, Shlipak MG. Marijuana Use and Estimated Glomerular Filtration Rate in Young Adults. Clin J Am Soc Nephrol. 2017 Aug 24.',
#     'Title': 'Marijuana Use and Estimated Glomerular Filtration Rate in Young Adults.',
#     'Year': '2017'},
#    {'AuthorList': 'Kazi DS, Penko J, Coxson PG, Moran AE, Ollendorf DA, Tice JA, Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2017-08-22T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/173083676',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28829863',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28829863'}],
#     'PublicationTitle': 'Kazi DS, Penko J, Coxson PG, Moran AE, Ollendorf DA, Tice JA, Bibbins-Domingo K. Updated Cost-effectiveness Analysis of PCSK9 Inhibitors Based on the Results of the FOURIER Trial. JAMA. 2017 08 22; 318(8):748-750.',
#     'Title': 'Updated Cost-effectiveness Analysis of PCSK9 Inhibitors Based on the Results of the FOURIER Trial.',
#     'Year': '2017'},
#    {'AuthorList': 'Grossman DC, Bibbins-Domingo K, Curry SJ',
#     'Claimed': True,
#     'Date': '2017-07-18T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/169890782',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28719688',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28719688'}],
#     'PublicationTitle': 'Grossman DC, Bibbins-Domingo K, Curry SJ. Screening Pelvic Examinations-Reply. JAMA. 2017 07 18; 318(3):300-301.',
#     'Title': 'Screening Pelvic Examinations-Reply.',
#     'Year': '2017'},
#    {'AuthorList': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#     'Claimed': True,
#     'Date': '2017-07-11T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/167533420',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28697260',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28697260'}],
#     'PublicationTitle': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW. Behavioral Counseling to Promote a Healthful Diet and Physical Activity for Cardiovascular Disease Prevention in Adults Without Cardiovascular Risk Factors: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Jul 11; 318(2):167-174.',
#     'Title': 'Behavioral Counseling to Promote a Healthful Diet and Physical Activity for Cardiovascular Disease Prevention in Adults Without Cardiovascular Risk Factors: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2017'},
#    {'AuthorList': 'Heller DJ, Coxson PG, Penko J, Pletcher MJ, Goldman L, Odden MC, Kazi DS, Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2017-07-07T00:00:00',
#     'Featured': None,
#     'Publication': 'Circulation',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/167120746',
#     'PublicationMedlineTA': 'Circulation',
#     'PublicationSource': [{'PMID': '28687710',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28687710'}],
#     'PublicationTitle': 'Heller DJ, Coxson PG, Penko J, Pletcher MJ, Goldman L, Odden MC, Kazi DS, Bibbins-Domingo K. Evaluating the Impact and Cost-Effectiveness of Statin Use Guidelines for Primary Prevention of Coronary Heart Disease and Stroke. Circulation. 2017 Sep 19; 136(12):1087-1098.',
#     'Title': 'Evaluating the Impact and Cost-Effectiveness of Statin Use Guidelines for Primary Prevention of Coronary Heart Disease and Stroke.',
#     'Year': '2017'},
#    {'AuthorList': 'Pignone MP, Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2017-07-01T00:00:00',
#     'Featured': None,
#     'Publication': 'The Medical clinics of North America',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/162263092',
#     'PublicationMedlineTA': 'Med Clin North Am',
#     'PublicationSource': [{'PMID': '28577631',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28577631'}],
#     'PublicationTitle': 'Pignone MP, Bibbins-Domingo K. Update on Key Clinical Preventive Services for Adults. Med Clin North Am. 2017 Jul; 101(4):xvii-xix.',
#     'Title': 'Update on Key Clinical Preventive Services for Adults.',
#     'Year': '2017'},
#    {'AuthorList': 'Kazi DS, Penko JM, Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2017-07-01T00:00:00',
#     'Featured': None,
#     'Publication': 'The Medical clinics of North America',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/162263093',
#     'PublicationMedlineTA': 'Med Clin North Am',
#     'PublicationSource': [{'PMID': '28577620',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28577620'}],
#     'PublicationTitle': 'Kazi DS, Penko JM, Bibbins-Domingo K. Statins for Primary Prevention of Cardiovascular Disease: Review of Evidence and Recommendations for Clinical Practice. Med Clin North Am. 2017 Jul; 101(4):689-699.',
#     'Title': 'Statins for Primary Prevention of Cardiovascular Disease: Review of Evidence and Recommendations for Clinical Practice.',
#     'Year': '2017'},
#    {'AuthorList': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#     'Claimed': True,
#     'Date': '2017-06-20T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/167120747',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28632874',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28632874'}],
#     'PublicationTitle': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW. Screening for Obesity in Children and Adolescents: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Jun 20; 317(23):2417-2426.',
#     'Title': 'Screening for Obesity in Children and Adolescents: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2017'},
#    {'AuthorList': 'Ben-Zeev A, Paluy Y, Milless KL, Goldstein EJ, Wallace L, Márquez-Magaña L, Bibbins-Domingo K, Estrada M',
#     'Claimed': True,
#     'Date': '2017-06-19T00:00:00',
#     'Featured': None,
#     'Publication': 'Education sciences',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/173610839',
#     'PublicationMedlineTA': 'Educ Sci (Basel)',
#     'PublicationSource': [{'PMID': '28835879',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28835879'}],
#     'PublicationTitle': "Ben-Zeev A, Paluy Y, Milless KL, Goldstein EJ, Wallace L, Márquez-Magaña L, Bibbins-Domingo K, Estrada M. 'Speaking Truth' Protects Underrepresented Minorities' Intellectual Performance and Safety in STEM. Educ Sci (Basel). 2017 Jun; 7(2).",
#     'Title': "'Speaking Truth' Protects Underrepresented Minorities' Intellectual Performance and Safety in STEM.",
#     'Year': '2017'},
#    {'AuthorList': 'Chen TK, Estrella MM, Vittinghoff E, Lin F, Gutierrez OM, Kramer H, Lewis CE, Kopp JB, Allen NB, Winkler CA, Bibbins-Domingo KB, Peralta CA',
#     'Claimed': True,
#     'Date': '2017-05-23T00:00:00',
#     'Featured': None,
#     'Publication': 'Kidney international',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/162263094',
#     'PublicationMedlineTA': 'Kidney Int',
#     'PublicationSource': [{'PMID': '28545715',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28545715'}],
#     'PublicationTitle': 'Chen TK, Estrella MM, Vittinghoff E, Lin F, Gutierrez OM, Kramer H, Lewis CE, Kopp JB, Allen NB, Winkler CA, Bibbins-Domingo KB, Peralta CA. APOL1 genetic variants are not associated with longitudinal blood pressure in young black adults. Kidney Int. 2017 Oct; 92(4):964-971.',
#     'Title': 'APOL1 genetic variants are not associated with longitudinal blood pressure in young black adults.',
#     'Year': '2017'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ',
#     'Claimed': True,
#     'Date': '2017-05-16T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/149329132',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28397958',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28397958'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ. The US Preventive Services Task Force 2017 Draft Recommendation Statement on Screening for Prostate Cancer: An Invitation to Review and Comment. JAMA. 2017 May 16; 317(19):1949-1950.',
#     'Title': 'The US Preventive Services Task Force 2017 Draft Recommendation Statement on Screening for Prostate Cancer: An Invitation to Review and Comment.',
#     'Year': '2017'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Siu AL, Tseng CW',
#     'Claimed': True,
#     'Date': '2017-05-09T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/162263095',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28492905',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28492905'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Siu AL, Tseng CW. Screening for Thyroid Cancer: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 May 09; 317(18):1882-1887.',
#     'Title': 'Screening for Thyroid Cancer: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2017'},
#    {'AuthorList': 'Kramer H, Colangelo L, Lewis CE, Jacobs DR, Pletcher M, Bibbins-Domingo K, Chang A, Siscovick D, Shlipak M, Peralta CA, Bansal N, Muntner P, Liu K',
#     'Claimed': True,
#     'Date': '2017-05-01T00:00:00',
#     'Featured': None,
#     'Publication': 'American journal of hypertension',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/146064005',
#     'PublicationMedlineTA': 'Am J Hypertens',
#     'PublicationSource': [{'PMID': '28338726',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28338726'}],
#     'PublicationTitle': 'Kramer H, Colangelo L, Lewis CE, Jacobs DR, Pletcher M, Bibbins-Domingo K, Chang A, Siscovick D, Shlipak M, Peralta CA, Bansal N, Muntner P, Liu K. Cumulative Exposure to Systolic Blood Pressure During Young Adulthood Through Midlife and the Urine Albumin-to-Creatinine Ratio at Midlife. Am J Hypertens. 2017 May 01; 30(5):502-509.',
#     'Title': 'Cumulative Exposure to Systolic Blood Pressure During Young Adulthood Through Midlife and the Urine Albumin-to-Creatinine Ratio at Midlife.',
#     'Year': '2017'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#     'Claimed': True,
#     'Date': '2017-04-25T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/152493885',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28444286',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28444286'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon MA, Tseng CW. Screening for Preeclampsia: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Apr 25; 317(16):1661-1667.',
#     'Title': 'Screening for Preeclampsia: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2017'},
#    {'AuthorList': 'Lunn MR, Obedin-Maliver J, Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2017-04-25T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/152493886',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28444268',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28444268'}],
#     'PublicationTitle': 'Lunn MR, Obedin-Maliver J, Bibbins-Domingo K. Estimating the Prevalence of Sexual Minority Adolescents. JAMA. 2017 04 25; 317(16):1691-1692.',
#     'Title': 'Estimating the Prevalence of Sexual Minority Adolescents.',
#     'Year': '2017'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Ebell M, Epling JW, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#     'Claimed': True,
#     'Date': '2017-03-28T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/146978504',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28350936',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28350936'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Ebell M, Epling JW, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW. Screening for Celiac Disease: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 03 28; 317(12):1252-1257.',
#     'Title': 'Screening for Celiac Disease: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2017'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon M, Siu AL, Tseng CW',
#     'Claimed': True,
#     'Date': '2017-03-07T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/143536187',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28267862',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28267862'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon M, Siu AL, Tseng CW. Screening for Gynecologic Conditions With Pelvic Examination: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 03 07; 317(9):947-953.',
#     'Title': 'Screening for Gynecologic Conditions With Pelvic Examination: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2017'},
#    {'AuthorList': 'Bibbins-Domingo K, Whitlock E, Wolff T, Ngo-Metzger Q, Phillips WR, Davidson KW, Krist AH, Lin JS, Mangione CM, Kurth AE, García FAR, Curry SJ, Grossman DC, Landefeld CS, Epling JW, Siu AL',
#     'Claimed': True,
#     'Date': '2017-03-07T00:00:00',
#     'Featured': None,
#     'Publication': 'Annals of internal medicine',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/143536188',
#     'PublicationMedlineTA': 'Ann Intern Med',
#     'PublicationSource': [{'PMID': '28265649',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28265649'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Whitlock E, Wolff T, Ngo-Metzger Q, Phillips WR, Davidson KW, Krist AH, Lin JS, Mangione CM, Kurth AE, García FAR, Curry SJ, Grossman DC, Landefeld CS, Epling JW, Siu AL. Developing Recommendations for Evidence-Based Clinical Preventive Services for Diverse Populations: Methods of the U.S. Preventive Services Task Force. Ann Intern Med. 2017 Apr 18; 166(8):565-571.',
#     'Title': 'Developing Recommendations for Evidence-Based Clinical Preventive Services for Diverse Populations: Methods of the U.S. Preventive Services Task Force.',
#     'Year': '2017'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW',
#     'Claimed': True,
#     'Date': '2017-01-24T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/140712977',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28118461',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28118461'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW. Screening for Obstructive Sleep Apnea in Adults: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Jan 24; 317(4):407-414.',
#     'Title': 'Screening for Obstructive Sleep Apnea in Adults: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2017'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW',
#     'Claimed': True,
#     'Date': '2017-01-10T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/137209449',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '28097362',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28097362'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW. Folic Acid Supplementation for the Prevention of Neural Tube Defects: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 01 10; 317(2):183-189.',
#     'Title': 'Folic Acid Supplementation for the Prevention of Neural Tube Defects: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2017'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW',
#     'Claimed': True,
#     'Date': '2016-12-20T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/133369762',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '27997659',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27997659'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW. Serologic Screening for Genital Herpes Infection: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 12 20; 316(23):2525-2530.',
#     'Title': 'Serologic Screening for Genital Herpes Infection: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2016'},
#    {'AuthorList': 'Grubbs V, Garcia F, Jue BL, Vittinghoff E, Ryder M, Lovett D, Carrillo J, Offenbacher S, Ganz P, Bibbins-Domingo K, Powe NR',
#     'Claimed': True,
#     'Date': '2016-12-20T00:00:00',
#     'Featured': None,
#     'Publication': 'Contemporary clinical trials',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/133369835',
#     'PublicationMedlineTA': 'Contemp Clin Trials',
#     'PublicationSource': [{'PMID': '28011387',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28011387'}],
#     'PublicationTitle': 'Grubbs V, Garcia F, Jue BL, Vittinghoff E, Ryder M, Lovett D, Carrillo J, Offenbacher S, Ganz P, Bibbins-Domingo K, Powe NR. The Kidney and Periodontal Disease (KAPD) study: A pilot randomized controlled trial testing the effect of non-surgical periodontal therapy on chronic kidney disease. Contemp Clin Trials. 2017 Feb; 53:143-150.',
#     'Title': 'The Kidney and Periodontal Disease (KAPD) study: A pilot randomized controlled trial testing the effect of non-surgical periodontal therapy on chronic kidney disease.',
#     'Year': '2016'},
#    {'AuthorList': 'Oh SS, Du R, Zeiger AM, McGarry ME, Hu D, Thakur N, Pino-Yanes M, Galanter JM, Eng C, Nishimura KK, Huntsman S, Farber HJ, Meade K, Avila P, Serebrisky D, Bibbins-Domingo K, Lenoir MA, Ford JG, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne SM, Sen S, Rodriguez-Santana JR, Williams K, Kumar R, Burchard EG',
#     'Claimed': True,
#     'Date': '2016-12-08T00:00:00',
#     'Featured': None,
#     'Publication': 'The Journal of asthma : official journal of the Association for the Care of Asthma',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/132444909',
#     'PublicationMedlineTA': 'J Asthma',
#     'PublicationSource': [{'PMID': '27929698',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27929698'}],
#     'PublicationTitle': 'Oh SS, Du R, Zeiger AM, McGarry ME, Hu D, Thakur N, Pino-Yanes M, Galanter JM, Eng C, Nishimura KK, Huntsman S, Farber HJ, Meade K, Avila P, Serebrisky D, Bibbins-Domingo K, Lenoir MA, Ford JG, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne SM, Sen S, Rodriguez-Santana JR, Williams K, Kumar R, Burchard EG. Breastfeeding associated with higher lung function in African American youths with asthma. J Asthma. 2016 Dec 08; 1-10.',
#     'Title': 'Breastfeeding associated with higher lung function in African American youths with asthma.',
#     'Year': '2016'},
#    {'AuthorList': 'Thakur N, Barcelo NE, Borrell LN, Singh S, Eng C, Davis A, Meade K, LeNoir MA, Avila PC, Farber HJ, Serebrisky D, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne S, Rodriguez-Santana JR, Sen S, Bibbins-Domingo K, Burchard EG',
#     'Claimed': True,
#     'Date': '2016-12-01T00:00:00',
#     'Featured': None,
#     'Publication': 'Chest',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/136107302',
#     'PublicationMedlineTA': 'Chest',
#     'PublicationSource': [{'PMID': '27916618',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27916618'}],
#     'PublicationTitle': 'Thakur N, Barcelo NE, Borrell LN, Singh S, Eng C, Davis A, Meade K, LeNoir MA, Avila PC, Farber HJ, Serebrisky D, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne S, Rodriguez-Santana JR, Sen S, Bibbins-Domingo K, Burchard EG. Perceived Discrimination Associated With Asthma and Related Outcomes in Minority Youth: The GALA II and SAGE II Studies. Chest. 2017 Apr; 151(4):804-812.',
#     'Title': 'Perceived Discrimination Associated With Asthma and Related Outcomes in Minority Youth: The GALA II and SAGE II Studies.',
#     'Year': '2016'},
#    {'AuthorList': 'Zaitlen N, Huntsman S, Hu D, Spear M, Eng C, Oh SS, White MJ, Mak A, Davis A, Meade K, Brigino-Buenaventura E, LeNoir MA, Bibbins-Domingo K, Burchard EG, Halperin E',
#     'Claimed': True,
#     'Date': '2016-11-22T00:00:00',
#     'Featured': None,
#     'Publication': 'Genetics',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/129242115',
#     'PublicationMedlineTA': 'Genetics',
#     'PublicationSource': [{'PMID': '27879348',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27879348'}],
#     'PublicationTitle': 'Zaitlen N, Huntsman S, Hu D, Spear M, Eng C, Oh SS, White MJ, Mak A, Davis A, Meade K, Brigino-Buenaventura E, LeNoir MA, Bibbins-Domingo K, Burchard EG, Halperin E. The Effects of Migration and Assortative Mating on Admixture Linkage Disequilibrium. Genetics. 2017 Jan; 205(1):375-383.',
#     'Title': 'The Effects of Migration and Assortative Mating on Admixture Linkage Disequilibrium.',
#     'Year': '2016'},
#    {'AuthorList': 'Kazi DS, Moran AE, Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2016-11-22T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/130513267',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '27893125',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27893125'}],
#     'PublicationTitle': 'Kazi DS, Moran AE, Bibbins-Domingo K. Cost-effectiveness of PCSK9 Inhibitor Therapy-Reply. JAMA. 2016 Nov 22; 316(20):2152.',
#     'Title': 'Cost-effectiveness of PCSK9 Inhibitor Therapy-Reply.',
#     'Year': '2016'},
#    {'AuthorList': 'Konfino J, Fernandez A, Penko J, Mason A, Martinez E, Coxson P, Heller D, Moran A, Bibbins-Domingo K, Pérez-Stable EJ, Mejía R',
#     'Claimed': True,
#     'Date': '2016-11-16T00:00:00',
#     'Featured': None,
#     'Publication': 'Journal of general internal medicine',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/128265828',
#     'PublicationMedlineTA': 'J Gen Intern Med',
#     'PublicationSource': [{'PMID': '27853916',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27853916'}],
#     'PublicationTitle': 'Konfino J, Fernandez A, Penko J, Mason A, Martinez E, Coxson P, Heller D, Moran A, Bibbins-Domingo K, Pérez-Stable EJ, Mejía R. Comparing Strategies for Lipid Lowering in Argentina: An Analysis from the CVD Policy Model-Argentina. J Gen Intern Med. 2017 May; 32(5):524-533.',
#     'Title': 'Comparing Strategies for Lipid Lowering in Argentina: An Analysis from the CVD Policy Model-Argentina.',
#     'Year': '2016'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Gillman MW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, LeFevre ML, Mangione CM, Phillips WR, Owens DK, Phipps MG, Pignone MP',
#     'Claimed': True,
#     'Date': '2016-11-15T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/127816615',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '27838723',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27838723'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Gillman MW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, LeFevre ML, Mangione CM, Phillips WR, Owens DK, Phipps MG, Pignone MP. Statin Use for the Primary Prevention of Cardiovascular Disease in Adults: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 Nov 15; 316(19):1997-2007.',
#     'Title': 'Statin Use for the Primary Prevention of Cardiovascular Disease in Adults: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2016'},
#    {'AuthorList': 'Georgiopoulou VV, Kalogeropoulos AP, Chowdhury R, Binongo JN, Bibbins-Domingo K, Rodondi N, Simonsick EM, Harris T, Newman AB, Kritchevsky SB, Butler J',
#     'Claimed': True,
#     'Date': '2016-11-14T00:00:00',
#     'Featured': None,
#     'Publication': 'American journal of preventive medicine',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/128265852',
#     'PublicationMedlineTA': 'Am J Prev Med',
#     'PublicationSource': [{'PMID': '27856115',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27856115'}],
#     'PublicationTitle': 'Georgiopoulou VV, Kalogeropoulos AP, Chowdhury R, Binongo JN, Bibbins-Domingo K, Rodondi N, Simonsick EM, Harris T, Newman AB, Kritchevsky SB, Butler J. Exercise Capacity, Heart Failure Risk, and Mortality in Older Adults: The Health ABC Study. Am J Prev Med. 2017 Feb; 52(2):144-153.',
#     'Title': 'Exercise Capacity, Heart Failure Risk, and Mortality in Older Adults: The Health ABC Study.',
#     'Year': '2016'},
#    {'AuthorList': 'Sánchez-Romero LM, Penko J, Coxson PG, Fernández A, Mason A, Moran AE, Ávila-Burgos L, Odden M, Barquera S, Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2016-11-01T00:00:00',
#     'Featured': None,
#     'Publication': 'PLoS medicine',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/125550651',
#     'PublicationMedlineTA': 'PLoS Med',
#     'PublicationSource': [{'PMID': '27802278',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27802278'}],
#     'PublicationTitle': "Sánchez-Romero LM, Penko J, Coxson PG, Fernández A, Mason A, Moran AE, Ávila-Burgos L, Odden M, Barquera S, Bibbins-Domingo K. Projected Impact of Mexico's Sugar-Sweetened Beverage Tax Policy on Diabetes and Cardiovascular Disease: A Modeling Study. PLoS Med. 2016 Nov; 13(11):e1002158.",
#     'Title': "Projected Impact of Mexico's Sugar-Sweetened Beverage Tax Policy on Diabetes and Cardiovascular Disease: A Modeling Study.",
#     'Year': '2016'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP',
#     'Claimed': True,
#     'Date': '2016-10-25T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/125550647',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '27784102',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27784102'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP. Primary Care Interventions to Support Breastfeeding: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 10 25; 316(16):1688-1693.',
#     'Title': 'Primary Care Interventions to Support Breastfeeding: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2016'},
#    {'AuthorList': 'Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2016-10-25T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/125550648',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '27784091',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27784091'}],
#     'PublicationTitle': 'Bibbins-Domingo K. Colorectal Cancer Screening Recommendations-Reply. JAMA. 2016 Oct 25; 316(16):1717.',
#     'Title': 'Colorectal Cancer Screening Recommendations-Reply.',
#     'Year': '2016'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Bauman L, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP',
#     'Claimed': True,
#     'Date': '2016-09-06T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/119164730',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '27599331',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27599331'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Bauman L, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP. Screening for Latent Tuberculosis Infection in Adults: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 Sep 06; 316(9):962-9.',
#     'Title': 'Screening for Latent Tuberculosis Infection in Adults: US Preventive Services Task Force Recommendation Statement.',
#     'Year': '2016'},
#    {'AuthorList': 'Kazi DS, Moran AE, Coxson PG, Penko J, Ollendorf DA, Pearson SD, Tice JA, Guzman D, Bibbins-Domingo K',
#     'Claimed': True,
#     'Date': '2016-08-16T00:00:00',
#     'Featured': '1',
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/116246030',
#     'PublicationMedlineTA': 'JAMA',
#     'PublicationSource': [{'PMID': '27533159',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27533159'}],
#     'PublicationTitle': 'Kazi DS, Moran AE, Coxson PG, Penko J, Ollendorf DA, Pearson SD, Tice JA, Guzman D, Bibbins-Domingo K. Cost-effectiveness of PCSK9 Inhibitor Therapy in Patients With Heterozygous Familial Hypercholesterolemia or Atherosclerotic Cardiovascular Disease. JAMA. 2016 Aug 16; 316(7):743-53.',
#     'Title': 'Cost-effectiveness of PCSK9 Inhibitor Therapy in Patients With Heterozygous Familial Hypercholesterolemia or Atherosclerotic Cardiovascular Disease.',
#     'Year': '2016'},
#    {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Gillman MW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, LeFevre M, Mangione CM, Owens DK, Phillips WR, Phipps MG, Pignone MP, Siu AL',
#     'Claimed': True,
#     'Date': '2016-08-09T00:00:00',
#     'Featured': None,
#     'Publication': 'JAMA',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/116246031',
#     'PublicationMedlineTA': 'JAMA',
# ...
#     'Title': 'BiDil for heart failure in black patients: implications of the U.S. Food and Drug Administration approval.',
#     'Year': '2007'},
#    {'AuthorList': 'Bibbins-Domingo K, Chertow GM, Fried LF, Odden MC, Newman AB, Kritchevsky SB, Harris TB, Satterfield S, Cummings SR, Shlipak MG',
#     'Claimed': True,
#     'Date': '2006-07-10T00:00:00',
#     'Featured': None,
#     'Publication': 'Archives of internal medicine',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/324786',
#     'PublicationMedlineTA': 'Arch Intern Med',
#     'PublicationSource': [{'PMID': '16832005',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/16832005'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Chertow GM, Fried LF, Odden MC, Newman AB, Kritchevsky SB, Harris TB, Satterfield S, Cummings SR, Shlipak MG. Renal function and heart failure risk in older black and white individuals: the Health, Aging, and Body Composition Study. Arch Intern Med. 2006 Jul 10; 166(13):1396-402.',
#     'Title': 'Renal function and heart failure risk in older black and white individuals: the Health, Aging, and Body Composition Study.',
#     'Year': '2006'},
#    {'AuthorList': 'Piette JD, Bibbins-Domingo K, Schillinger D',
#     'Claimed': True,
#     'Date': '2005-01-21T00:00:00',
#     'Featured': None,
#     'Publication': 'Patient education and counseling',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/323448',
#     'PublicationMedlineTA': 'Patient Educ Couns',
#     'PublicationSource': [{'PMID': '16332469',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/16332469'}],
#     'PublicationTitle': "Piette JD, Bibbins-Domingo K, Schillinger D. Health care discrimination, processes of care, and diabetes patients' health status. Patient Educ Couns. 2006 Jan; 60(1):41-8.",
#     'Title': "Health care discrimination, processes of care, and diabetes patients' health status.",
#     'Year': '2005'},
#    {'AuthorList': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG',
#     'Claimed': True,
#     'Date': '2005-01-15T00:00:00',
#     'Featured': None,
#     'Publication': 'The American journal of cardiology',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/321446',
#     'PublicationMedlineTA': 'Am J Cardiol',
#     'PublicationSource': [{'PMID': '15642574',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15642574'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG. Effect of hormone therapy on mortality rates among women with heart failure and coronary artery disease. Am J Cardiol. 2005 Jan 15; 95(2):289-91.',
#     'Title': 'Effect of hormone therapy on mortality rates among women with heart failure and coronary artery disease.',
#     'Year': '2005'},
#    {'AuthorList': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Grady D, Shlipak MG',
#     'Claimed': True,
#     'Date': '2004-10-19T00:00:00',
#     'Featured': None,
#     'Publication': 'Journal of the American College of Cardiology',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/321003',
#     'PublicationMedlineTA': 'J Am Coll Cardiol',
#     'PublicationSource': [{'PMID': '15489091',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15489091'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Grady D, Shlipak MG. Renal insufficiency as an independent predictor of mortality among women with heart failure. J Am Coll Cardiol. 2004 Oct 19; 44(8):1593-600.',
#     'Title': 'Renal insufficiency as an independent predictor of mortality among women with heart failure.',
#     'Year': '2004'},
#    {'AuthorList': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG',
#     'Claimed': True,
#     'Date': '2004-09-07T00:00:00',
#     'Featured': None,
#     'Publication': 'Circulation',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/272249',
#     'PublicationMedlineTA': 'Circulation',
#     'PublicationSource': [{'PMID': '15353499',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15353499'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG. Predictors of heart failure among women with coronary disease. Circulation. 2004 Sep 14; 110(11):1424-30.',
#     'Title': 'Predictors of heart failure among women with coronary disease.',
#     'Year': '2004'},
#    {'AuthorList': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA',
#     'Claimed': True,
#     'Date': '2004-04-15T00:00:00',
#     'Featured': None,
#     'Publication': 'The American journal of medicine',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/319953',
#     'PublicationMedlineTA': 'Am J Med',
#     'PublicationSource': [{'PMID': '15063811',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15063811'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA. Is B-type natriuretic peptide a useful screening test for systolic or diastolic dysfunction in patients with coronary disease? Data from the Heart and Soul Study. Am J Med. 2004 Apr 15; 116(8):509-16.',
#     'Title': 'Is B-type natriuretic peptide a useful screening test for systolic or diastolic dysfunction in patients with coronary disease? Data from the Heart and Soul Study.',
#     'Year': '2004'},
#    {'AuthorList': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA',
#     'Claimed': True,
#     'Date': '2003-12-08T00:00:00',
#     'Featured': None,
#     'Publication': 'Circulation',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/261298',
#     'PublicationMedlineTA': 'Circulation',
#     'PublicationSource': [{'PMID': '14662720',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/14662720'}],
#     'PublicationTitle': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA. B-type natriuretic peptide and ischemia in patients with stable coronary disease: data from the Heart and Soul study. Circulation. 2003 Dec 16; 108(24):2987-92.',
#     'Title': 'B-type natriuretic peptide and ischemia in patients with stable coronary disease: data from the Heart and Soul study.',
#     'Year': '2003'},
#    {'AuthorList': 'Schillinger D, Bibbins-Domingo K, Vranizan K, Bacchetti P, Luce JM, Bindman AB',
#     'Claimed': True,
#     'Date': '2000-05-01T00:00:00',
#     'Featured': None,
#     'Publication': 'Journal of general internal medicine',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/313775',
#     'PublicationMedlineTA': 'J Gen Intern Med',
#     'PublicationSource': [{'PMID': '10840268',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/10840268'}],
#     'PublicationTitle': 'Schillinger D, Bibbins-Domingo K, Vranizan K, Bacchetti P, Luce JM, Bindman AB. Effects of primary care coordination on public hospital patients. J Gen Intern Med. 2000 May; 15(5):329-36.',
#     'Title': 'Effects of primary care coordination on public hospital patients.',
#     'Year': '2000'},
#    {'AuthorList': 'Boeuf H, Murphy J, Bibbins KB, Varmus HE',
#     'Claimed': True,
#     'Date': '1995-02-02T00:00:00',
#     'Featured': None,
#     'Publication': 'Oncogene',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/241654',
#     'PublicationMedlineTA': 'Oncogene',
#     'PublicationSource': [{'PMID': '7531318',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/7531318'}],
#     'PublicationTitle': 'Boeuf H, Murphy J, Bibbins KB, Varmus HE. Binding in vitro of phosphotyrosine-containing proteins to pp60c-src SH2 domain does not correlate with CEF transformation. Oncogene. 1995 Feb 02; 10(3):433-8.',
#     'Title': 'Binding in vitro of phosphotyrosine-containing proteins to pp60c-src SH2 domain does not correlate with CEF transformation.',
#     'Year': '1995'},
#    {'AuthorList': 'Kaplan KB, Bibbins KB, Swedlow JR, Arnaud M, Morgan DO, Varmus HE',
#     'Claimed': True,
#     'Date': '1994-10-17T00:00:00',
#     'Featured': None,
#     'Publication': 'The EMBO journal',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/234511',
#     'PublicationMedlineTA': 'EMBO J',
#     'PublicationSource': [{'PMID': '7525268',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/7525268'}],
#     'PublicationTitle': 'Kaplan KB, Bibbins KB, Swedlow JR, Arnaud M, Morgan DO, Varmus HE. Association of the amino-terminal half of c-Src with focal adhesions alters their properties and is regulated by phosphorylation of tyrosine 527. EMBO J. 1994 Oct 17; 13(20):4745-56.',
#     'Title': 'Association of the amino-terminal half of c-Src with focal adhesions alters their properties and is regulated by phosphorylation of tyrosine 527.',
#     'Year': '1994'},
#    {'AuthorList': 'Bibbins KB, Boeuf H, Varmus HE',
#     'Claimed': True,
#     'Date': '1993-12-01T00:00:00',
#     'Featured': None,
#     'Publication': 'Molecular and cellular biology',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/234440',
#     'PublicationMedlineTA': 'Mol Cell Biol',
#     'PublicationSource': [{'PMID': '7504171',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/7504171'}],
#     'PublicationTitle': 'Bibbins KB, Boeuf H, Varmus HE. Binding of the Src SH2 domain to phosphopeptides is determined by residues in both the SH2 domain and the phosphopeptides. Mol Cell Biol. 1993 Dec; 13(12):7278-87.',
#     'Title': 'Binding of the Src SH2 domain to phosphopeptides is determined by residues in both the SH2 domain and the phosphopeptides.',
#     'Year': '1993'},
#    {'AuthorList': 'Bibbins KB, Tsai JY, Schimenti J, Sarvetnick N, Zoghbi HY, Goodfellow P, Silver LM',
#     'Claimed': True,
#     'Date': '1989-07-01T00:00:00',
#     'Featured': None,
#     'Publication': 'Genomics',
#     'PublicationCategory': None,
#     'PublicationID': 'http://profiles.ucsf.edu/profile/223263',
#     'PublicationMedlineTA': 'Genomics',
#     'PublicationSource': [{'PMID': '2767684',
#       'PublicationSourceName': 'PubMed',
#       'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/2767684'}],
#     'PublicationTitle': 'Bibbins KB, Tsai JY, Schimenti J, Sarvetnick N, Zoghbi HY, Goodfellow P, Silver LM. Human homologs of two testes-expressed loci on mouse chromosome 17 map to opposite arms of chromosome 6. Genomics. 1989 Jul; 5(1):139-43.',
#     'Title': 'Human homologs of two testes-expressed loci on mouse chromosome 17 map to opposite arms of chromosome 6.',
#     'Year': '1989'}],
#   'ResearchActivitiesAndFunding': [{'EndDate': '2022-08-31',
#     'Role': 'Principal Investigator',
#     'Sponsor': 'NIH/NHLBI',
#     'SponsorAwardID': 'K12HL138046',
#     'StartDate': '2017-09-01',
#     'Title': 'UCSF Career Development Program in Implementation Research in Heart and Lung Diseases'},
#    {'EndDate': '2021-05-31',
#     'Role': 'Principal Investigator',
#     'Sponsor': 'NIH/NCATS',
#     'SponsorAwardID': 'TL1TR001871',
#     'StartDate': '2016-07-18',
#     'Title': 'NRSA Training Core'},
#    {'EndDate': '2021-05-31',
#     'Role': 'Co-Principal Investigator',
#     'Sponsor': 'NIH/NCATS',
#     'SponsorAwardID': 'KL2TR001870',
#     'StartDate': '2016-07-18',
#     'Title': 'Institutional Career Development Core'},
#    {'EndDate': '2019-07-31',
#     'Role': 'Principal Investigator',
#     'Sponsor': 'NIH/NIDDK',
#     'SponsorAwardID': 'K24DK103992',
#     'StartDate': '2014-09-20',
#     'Title': 'Hypertension Management in Minority and Low-income Populations'},
#    {'EndDate': '2019-06-30',
#     'Role': 'Co-Principal Investigator',
#     'Sponsor': 'NIH/NIMHD',
#     'SponsorAwardID': 'TL4MD009638',
#     'StartDate': '2014-09-26',
#     'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#    {'EndDate': '2019-06-30',
#     'Role': 'Co-Principal Investigator',
#     'Sponsor': 'NIH/NIGMS',
#     'SponsorAwardID': 'UL1GM118985',
#     'StartDate': '2014-09-26',
#     'Title': 'SF BUILD: Enabling Students to Represnt in Science'},
#    {'EndDate': '2019-06-30',
#     'Role': 'Co-Principal Investigator',
#     'Sponsor': 'NIH/NIGMS',
#     'SponsorAwardID': 'RL5GM118984',
#     'StartDate': '2014-09-26',
#     'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#    {'EndDate': '2019-06-30',
#     'Role': 'Co-Principal Investigator',
#     'Sponsor': 'NIH/NIMHD',
#     'SponsorAwardID': 'RL5MD009599',
#     'StartDate': '2014-09-26',
#     'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#    {'EndDate': '2019-06-30',
#     'Role': 'Co-Principal Investigator',
#     'Sponsor': 'NIH/NIGMS',
#     'SponsorAwardID': 'TL4GM118986',
#     'StartDate': '2014-09-26',
#     'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#    {'EndDate': '2019-06-30',
#     'Role': 'Co-Principal Investigator',
#     'Sponsor': 'NIH/NIMHD',
#     'SponsorAwardID': 'UL1MD009608',
#     'StartDate': '2014-09-26',
#     'Title': 'SF BUILD: Enabling Students to Represnt in Science'},
#    {'EndDate': '2018-06-30',
#     'Role': 'Co-Principal Investigator',
#     'Sponsor': 'NIH',
#     'SponsorAwardID': 'OT2OD025276',
#     'StartDate': '2017-07-23',
#     'Title': 'All of Us Research Program National Sexual and Gender Minority Engagement Network'},
#    {'EndDate': '2018-05-31',
#     'Role': 'Principal Investigator',
#     'Sponsor': 'NIH/NHLBI',
#     'SponsorAwardID': 'R25HL126146',
#     'StartDate': '2014-09-15',
#     'Title': 'UCSF Research in Implementation Sciences for Equity (RISE)'},
#    {'EndDate': '2017-08-31',
#     'Role': 'Co-Principal Investigator',
#     'Sponsor': 'NIH/NINDS',
#     'SponsorAwardID': 'U54NS081760',
#     'StartDate': '2012-09-30',
#     'Title': 'The Discovering Healthcare Innovations to Address Disparties in Stroke (DIADS) pr'},
#    {'EndDate': '2017-02-28',
#     'Role': 'Principal Investigator',
#     'Sponsor': 'NIH/NIMHD',
#     'SponsorAwardID': 'P60MD006902',
#     'StartDate': '2012-08-27',
#     'Title': 'Addressing disparities in chronic disease with a teen and young adult focus'},
#    {'EndDate': '2016-02-29',
#     'Role': 'Principal Investigator',
#     'Sponsor': 'NIH/FIC',
#     'SponsorAwardID': 'R03TW009061',
#     'StartDate': '2013-03-20',
#     'Title': 'Enhancing Mexican Capacity for CVD Policy Research'},
#    {'EndDate': '2012-07-31',
#     'Role': 'Principal Investigator',
#     'Sponsor': 'NIH/NIDDK',
#     'SponsorAwardID': 'R01DK078124',
#     'StartDate': '2008-08-01',
#     'Title': 'Chronic Kidney Disease and Cardiovascular Risk in Black and White Young Adults'}],
#   'School': 'UCSF School of Medicine',
#   'SlideShare_beta': [],
#   'Title': 'Professor',
#   'Titles': ['Professor'],
#   'Twitter_beta': ['ucsfcvp'],
#   'Videos': [{'label': 'Mission in a Minute',
#     'url': 'https://www.youtube.com/watch?v=DxLJwwvcg-o&index=1&list=PLVLbDUiGesPyQqgEEsceWk4-FzSmMeI_d'},
#    {'label': 'A Life in Medicine: People Shaping Healthcare Today',
#     'url': 'https://youtu.be/lzivJjGwPdU'}],
#   'WebLinks_beta': [{'Label': 'UCSF Center for Vulnerable Populations at San Francisco General Hospital',
#     'URL': 'http://cvp.ucsf.edu/'},
#    {'Label': 'UCSF CTSI K Scholars Program',
#     'URL': 'http://ctsi.ucsf.edu/our-work/k-scholars-program'},
#    {'Label': 'Sugar Science',
#     'URL': 'http://sugarscience.org/sugarscientist-team/#.VGFBsvTF-wA'},
#    {'Label': 'Bring It Down Stroke Study',
#     'URL': 'http://www.bringitdownstudy.org/'}]}]

# %% [markdown]
# Looking at this data, we can see the [] denoting a list.  Let's check the type and length

# %%
print(type(profiles))
print(len(profiles))
# Out:
# <class 'list'>
# 1

# %% [markdown]
# There is only one element to this list, so let's grab it and take a look...

# %%
profile = profiles[0]

# %%
profile
# Out:
# {'Address': {'Address1': '550 16th. Street',
#   'Address2': 'San Francisco, CA 94158',
#   'Address3': None,
#   'Address4': None,
#   'Fax': '415-514-8150',
#   'Latitude': '37.755637',
#   'Longitude': '-122.405102',
#   'Telephone': '415-502-4106'},
#  'AwardOrHonors': [{'AwardConferredBy': None,
#    'AwardEndDate': None,
#    'AwardLabel': 'Association of American Physicians',
#    'AwardStartDate': '2017',
#    'Summary': 'Association of American Physicians, 2017'},
#   {'AwardConferredBy': None,
#    'AwardEndDate': None,
#    'AwardLabel': 'National Academy of Medicine',
#    'AwardStartDate': '2015',
#    'Summary': 'National Academy of Medicine, 2015'},
#   {'AwardConferredBy': None,
#    'AwardEndDate': None,
#    'AwardLabel': 'Mid-career Research Mentor Award - Society of General Internal Medicine',
#    'AwardStartDate': '2014',
#    'Summary': 'Mid-career Research Mentor Award - Society of General Internal Medicine, 2014'},
#   {'AwardConferredBy': None,
#    'AwardEndDate': None,
#    'AwardLabel': 'Lee Goldman, MD Endowed Chair in Medicine',
#    'AwardStartDate': '2012',
#    'Summary': 'Lee Goldman, MD Endowed Chair in Medicine, 2012'},
#   {'AwardConferredBy': None,
#    'AwardEndDate': None,
#    'AwardLabel': 'American Society for Clinical Investigation',
#    'AwardStartDate': '2010',
#    'Summary': 'American Society for Clinical Investigation, 2010'}],
#  'Department': 'Epidemiology & Biostatistics',
#  'Education_Training': [{'degree': 'MAS',
#    'department_or_school': 'Epidemiology and Biostatistics',
#    'end_date': '2004',
#    'organization': 'University of California, San Francisco',
#    'start_date': ''},
#   {'degree': 'Residency',
#    'department_or_school': 'Medicine',
#    'end_date': '2001',
#    'organization': 'University of California, San Francisco',
#    'start_date': ''},
#   {'degree': 'MD',
#    'department_or_school': 'Medicine',
#    'end_date': '1999',
#    'organization': 'University of California, San Francisco',
#    'start_date': ''},
#   {'degree': 'PhD',
#    'department_or_school': 'Graduate Division (Biochemistry)',
#    'end_date': '1994',
#    'organization': 'University of California, San Francisco',
#    'start_date': ''},
#   {'degree': 'AB',
#    'department_or_school': 'Molecular Biology',
#    'end_date': '1987',
#    'organization': 'Princeton University',
#    'start_date': ''}],
#  'Email': 'kirsten.bibbins-domingo@ucsf.edu',
#  'FirstName': 'Kirsten',
#  'FreetextKeywords': ['Chronic disease prevention',
#   'Cardiovascular disease',
#   'Health of young adults',
#   'Kidney disease',
#   'Health disparities'],
#  'GlobalHealth_beta': {'Countries': ['Argentina',
#    'Chile',
#    'China',
#    'Mexico',
#    'Puerto Rico',
#    'United States']},
#  'Keywords': ['Primary Prevention',
#   'Cardiovascular Diseases',
#   'Hypertension',
#   'Advisory Committees',
#   'Mass Screening'],
#  'LastName': 'Bibbins-Domingo',
#  'MediaLinks_beta': [{'Date': '2017-08-22',
#    'Label': 'UCSF to Lead Gathering of Important Health Information for Sexual, Gender Minorities',
#    'URL': 'https://www.ucsf.edu/news/2017/08/408116/ucsf-lead-gathering-important-health-information-sexual-gender-minorities'},
#   {'Date': '2017-07-21',
#    'Label': 'Kirsten Bibbins-Domingo, PhD, MD, MAS Appointed as Chair of Epidemiology and Biostatistics and Inaugural Vice Dean for Population Health and Health Equity',
#    'URL': 'https://medschool.ucsf.edu/kirsten-bibbins-domingo-phd-md-mas-appointed-chair-epidemiology-and-biostatistics-and-inaugural-vice'},
#   {'Date': '2017-04-17',
#    'Label': 'KQED Forum with Michael Krasny',
#    'URL': 'https://ww2.kqed.org/forum/2017/04/14/new-guidelines-let-patients-opt-in-to-controversial-prostate-cancer-screening/'},
#   {'Date': '2017-02-07',
#    'Label': 'In Decade Since Founding, UCSF’s Center for Vulnerable Populations Has Innovated Research, Care',
#    'URL': 'https://www.ucsf.edu/news/2017/02/405736/decade-founding-ucsfs-center-vulnerable-populations-has-innovated-research-care'},
#   {'Date': '2016-11-01',
#    'Label': 'Do soda taxes work? Experts look to Mexico',
#    'URL': 'http://www.cnn.com/2016/11/01/health/soda-tax-benefits-mexico/index.html'},
#   {'Date': '2016-09-15',
#    'Label': 'In a first, aspirin is recommended to fight a form of cancer',
#    'URL': 'http://well.blogs.nytimes.com/2015/09/14/in-a-first-aspirin-is-recommended-to-fight-a-form-of-cancer/?_r=0'},
#   {'Date': '2016-08-26',
#    'Label': 'Cost of New Cholesterol Drug Unsustainable',
#    'URL': 'https://www.ucsf.edu/news/2016/08/403891/cost-new-cholesterol-drugs-unsustainable-says-study'},
#   {'Date': '2015-06-25',
#    'Label': 'UCSF Researchers Launch Landmark Study of LGBTQ Community Health',
#    'URL': 'https://www.ucsf.edu/news/2015/06/130631/ucsf-researchers-launch-landmark-study-lgbtq-community-health'},
#   {'Date': '2015-04-29',
#    'Label': 'New breast cancer screening guidelines explained',
#    'URL': 'http://www.washingtonpost.com/news/to-your-health/wp/2015/04/29/new-breast-cancer-screening-guidelines-explained/'},
#   {'Date': '2015-04-20',
#    'Label': 'Statin Use in Elderly Would Prevent Disease But Could Carry Considerable Side Effects',
#    'URL': 'http://www.ucsf.edu/news/2015/04/125236/statin-use-elderly-would-prevent-disease-could-carry-considerable-side-effects'},
#   {'Date': '2014-11-10',
#    'Label': 'SFSU and UCSF Awarded $17 Million to Increase Diversity in the Biomedical',
#    'URL': 'http://ctsi.ucsf.edu/news/about-ctsi/sfsu-and-ucsf-awarded-17-million-increase-diversity-biomedical-workforce'},
#   {'Date': '2014-10-23',
#    'Label': 'S.F. State receives $17 million grant to help minorities',
#    'URL': 'http://www.sfgate.com/education/article/S-F-State-receives-17-million-grant-to-help-5843661.php'},
#   {'Date': '2014-01-05',
#    'Label': "Bay Area's People to Watch in 2014",
#    'URL': 'http://www.sfgate.com/bayarea/article/Bay-Area-s-People-to-Watch-in-2014-5114765.php'},
#   {'Date': '2013-06-04',
#    'Label': "Q&A With Director of UCSF's K Scholars Program",
#    'URL': 'http://www.ucsf.edu/news/2013/06/106411/qa-co-director-ucsf-k-scholars-program'},
#   {'Date': '2013-02-11',
#    'Label': 'Reducing Sodium in American Diet Would Save Hundreds of Thousands of Lives',
#    'URL': 'http://www.ucsf.edu/news/2013/02/13516/reducing-sodium-american-diet-would-save-hundreds-thousands-lives'},
#   {'Date': '2012-09-04',
#    'Label': 'Undergraduates Get Hands-On Experience with Clinical Research',
#    'URL': 'http://www.ucsf.edu/news/2012/09/12662/undergraduates-get-hands-experience-clinical-research'},
#   {'Date': '2012-01-09',
#    'Label': 'How Many Lives Could a Soda Tax Save?',
#    'URL': 'http://www.ucsf.edu/news/2012/01/11267/how-many-lives-could-soda-tax-save'}],
#  'NIHGrants_beta': [{'NIHFiscalYear': '2018',
#    'NIHProjectNumber': 'OT2OD025276',
#    'Title': 'All of Us Research Program National Sexual and Gender Minority Engagement Network',
#    'api_notes': 'Deprecated, use ResearchActivitiesAndFunding instead. The fiscal year may be off.'}],
#  'Name': 'Kirsten Bibbins-Domingo, MD, PhD, MAS',
#  'Narrative': 'Kirsten Bibbins-Domingo, PhD, MD, MAS is the Lee Goldman, MD Endowed Chair in Medicine and Professor of Epidemiology and Biostatistics and Medicine. She is the Vice Dean for Population Health and Health Equity in the UCSF School of Medicine, and she directs the UCSF Center for Vulnerable Populations at Zuckerberg San Francisco General Hospital, a research center focused on discovery, implementation, policy, advocacy, and community engagement for communities at risk for poor health and inadequate healthcare.  She is the Director of the CTSI Clinical and Translational Science Training (CTST) Programs.  A general internist at Zuckerberg San Francisco General Hospital, Dr. Bibbins-Domingo has expertise in cardiovascular disease, diabetes, and chronic kidney disease with a particular interest in the development of chronic disease in young adults.  Her work focuses on racial, ethnic and income differences in manifestations of chronic disease and effective clinical, public health, and policy interventions aimed at prevention.  She leads the UCSF computer simulation modeling group using the Cardiovascular Disease Policy Model.  Dr. Bibbins-Domingo is the PI or joint PI of three collaborative center grants from the NIH: the NIMHD P60 Center for Health And Risk in Minority youth and adults (CHARM) addressing disparities in chronic disease in youth and young adults, Bring It Down  an NINDS U54 research center addressing stroke prevention and stroke disparities in collaboration with Kaiser Permanente Northern California, and BUILD  a NIGMS U54 infrastructure and training grant with San Francisco State University.  She has been a member of the US Preventive Services Task Force since 2010 and is the Immediate Past Chair. She is a member of the American Society for Clinical Investigation, the National Academy of Medicine, and the Association of American Physicians.',
#  'PhotoURL': 'http://profiles.ucsf.edu/profile/Modules/CustomViewPersonGeneralInfo/PhotoHandler.ashx?NodeID=370012',
#  'ProfilesURL': 'http://profiles.ucsf.edu/kirsten.bibbins-domingo',
#  'PublicationCount': '218',
#  'Publications': [{'AuthorList': 'Hiatt RA, Handley MA, Ling PM, Burchard E, Thakur N, Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2017-09-01T00:00:00',
#    'Featured': None,
#    'Publication': 'American journal of preventive medicine',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/173083677',
#    'PublicationMedlineTA': 'Am J Prev Med',
#    'PublicationSource': [{'PMID': '28818252',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28818252'}],
#    'PublicationTitle': 'Hiatt RA, Handley MA, Ling PM, Burchard E, Thakur N, Bibbins-Domingo K. Origins of Cancer Disparities in Young Adults: Logic Models to Guide Research. Am J Prev Med. 2017 Sep; 53(3S1):S95-S102.',
#    'Title': 'Origins of Cancer Disparities in Young Adults: Logic Models to Guide Research.',
#    'Year': '2017'},
#   {'AuthorList': 'Ling PM, Holmes LM, Jordan JW, Lisha NE, Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2017-09-01T00:00:00',
#    'Featured': None,
#    'Publication': 'American journal of preventive medicine',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/173083678',
#    'PublicationMedlineTA': 'Am J Prev Med',
#    'PublicationSource': [{'PMID': '28818250',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28818250'}],
#    'PublicationTitle': 'Ling PM, Holmes LM, Jordan JW, Lisha NE, Bibbins-Domingo K. Bars, Nightclubs, and Cancer Prevention: New Approaches to Reduce Young Adult Cigarette Smoking. Am J Prev Med. 2017 Sep; 53(3S1):S78-S85.',
#    'Title': 'Bars, Nightclubs, and Cancer Prevention: New Approaches to Reduce Young Adult Cigarette Smoking.',
#    'Year': '2017'},
#   {'AuthorList': 'Schillinger D, Ling PM, Fine S, Boyer CB, Rogers E, Vargas RA, Bibbins-Domingo K, Chou WS',
#    'Claimed': True,
#    'Date': '2017-09-01T00:00:00',
#    'Featured': None,
#    'Publication': 'American journal of preventive medicine',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/173083679',
#    'PublicationMedlineTA': 'Am J Prev Med',
#    'PublicationSource': [{'PMID': '28818240',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28818240'}],
#    'PublicationTitle': 'Schillinger D, Ling PM, Fine S, Boyer CB, Rogers E, Vargas RA, Bibbins-Domingo K, Chou WS. Reducing Cancer and Cancer Disparities: Lessons From a Youth-Generated Diabetes Prevention Campaign. Am J Prev Med. 2017 Sep; 53(3S1):S103-S113.',
#    'Title': 'Reducing Cancer and Cancer Disparities: Lessons From a Youth-Generated Diabetes Prevention Campaign.',
#    'Year': '2017'},
#   {'AuthorList': 'Ishida JH, Auer R, Vittinghoff E, Pletcher MJ, Reis JP, Sidney S, Johansen KL, Bibbins-Domingo K, Peralta CA, Shlipak MG',
#    'Claimed': True,
#    'Date': '2017-08-24T00:00:00',
#    'Featured': None,
#    'Publication': 'Clinical journal of the American Society of Nephrology : CJASN',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/173610838',
#    'PublicationMedlineTA': 'Clin J Am Soc Nephrol',
#    'PublicationSource': [{'PMID': '28838990',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28838990'}],
#    'PublicationTitle': 'Ishida JH, Auer R, Vittinghoff E, Pletcher MJ, Reis JP, Sidney S, Johansen KL, Bibbins-Domingo K, Peralta CA, Shlipak MG. Marijuana Use and Estimated Glomerular Filtration Rate in Young Adults. Clin J Am Soc Nephrol. 2017 Aug 24.',
#    'Title': 'Marijuana Use and Estimated Glomerular Filtration Rate in Young Adults.',
#    'Year': '2017'},
#   {'AuthorList': 'Kazi DS, Penko J, Coxson PG, Moran AE, Ollendorf DA, Tice JA, Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2017-08-22T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/173083676',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28829863',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28829863'}],
#    'PublicationTitle': 'Kazi DS, Penko J, Coxson PG, Moran AE, Ollendorf DA, Tice JA, Bibbins-Domingo K. Updated Cost-effectiveness Analysis of PCSK9 Inhibitors Based on the Results of the FOURIER Trial. JAMA. 2017 08 22; 318(8):748-750.',
#    'Title': 'Updated Cost-effectiveness Analysis of PCSK9 Inhibitors Based on the Results of the FOURIER Trial.',
#    'Year': '2017'},
#   {'AuthorList': 'Grossman DC, Bibbins-Domingo K, Curry SJ',
#    'Claimed': True,
#    'Date': '2017-07-18T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/169890782',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28719688',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28719688'}],
#    'PublicationTitle': 'Grossman DC, Bibbins-Domingo K, Curry SJ. Screening Pelvic Examinations-Reply. JAMA. 2017 07 18; 318(3):300-301.',
#    'Title': 'Screening Pelvic Examinations-Reply.',
#    'Year': '2017'},
#   {'AuthorList': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#    'Claimed': True,
#    'Date': '2017-07-11T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/167533420',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28697260',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28697260'}],
#    'PublicationTitle': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW. Behavioral Counseling to Promote a Healthful Diet and Physical Activity for Cardiovascular Disease Prevention in Adults Without Cardiovascular Risk Factors: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Jul 11; 318(2):167-174.',
#    'Title': 'Behavioral Counseling to Promote a Healthful Diet and Physical Activity for Cardiovascular Disease Prevention in Adults Without Cardiovascular Risk Factors: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2017'},
#   {'AuthorList': 'Heller DJ, Coxson PG, Penko J, Pletcher MJ, Goldman L, Odden MC, Kazi DS, Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2017-07-07T00:00:00',
#    'Featured': None,
#    'Publication': 'Circulation',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/167120746',
#    'PublicationMedlineTA': 'Circulation',
#    'PublicationSource': [{'PMID': '28687710',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28687710'}],
#    'PublicationTitle': 'Heller DJ, Coxson PG, Penko J, Pletcher MJ, Goldman L, Odden MC, Kazi DS, Bibbins-Domingo K. Evaluating the Impact and Cost-Effectiveness of Statin Use Guidelines for Primary Prevention of Coronary Heart Disease and Stroke. Circulation. 2017 Sep 19; 136(12):1087-1098.',
#    'Title': 'Evaluating the Impact and Cost-Effectiveness of Statin Use Guidelines for Primary Prevention of Coronary Heart Disease and Stroke.',
#    'Year': '2017'},
#   {'AuthorList': 'Pignone MP, Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2017-07-01T00:00:00',
#    'Featured': None,
#    'Publication': 'The Medical clinics of North America',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/162263092',
#    'PublicationMedlineTA': 'Med Clin North Am',
#    'PublicationSource': [{'PMID': '28577631',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28577631'}],
#    'PublicationTitle': 'Pignone MP, Bibbins-Domingo K. Update on Key Clinical Preventive Services for Adults. Med Clin North Am. 2017 Jul; 101(4):xvii-xix.',
#    'Title': 'Update on Key Clinical Preventive Services for Adults.',
#    'Year': '2017'},
#   {'AuthorList': 'Kazi DS, Penko JM, Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2017-07-01T00:00:00',
#    'Featured': None,
#    'Publication': 'The Medical clinics of North America',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/162263093',
#    'PublicationMedlineTA': 'Med Clin North Am',
#    'PublicationSource': [{'PMID': '28577620',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28577620'}],
#    'PublicationTitle': 'Kazi DS, Penko JM, Bibbins-Domingo K. Statins for Primary Prevention of Cardiovascular Disease: Review of Evidence and Recommendations for Clinical Practice. Med Clin North Am. 2017 Jul; 101(4):689-699.',
#    'Title': 'Statins for Primary Prevention of Cardiovascular Disease: Review of Evidence and Recommendations for Clinical Practice.',
#    'Year': '2017'},
#   {'AuthorList': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#    'Claimed': True,
#    'Date': '2017-06-20T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/167120747',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28632874',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28632874'}],
#    'PublicationTitle': 'Grossman DC, Bibbins-Domingo K, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW. Screening for Obesity in Children and Adolescents: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Jun 20; 317(23):2417-2426.',
#    'Title': 'Screening for Obesity in Children and Adolescents: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2017'},
#   {'AuthorList': 'Ben-Zeev A, Paluy Y, Milless KL, Goldstein EJ, Wallace L, Márquez-Magaña L, Bibbins-Domingo K, Estrada M',
#    'Claimed': True,
#    'Date': '2017-06-19T00:00:00',
#    'Featured': None,
#    'Publication': 'Education sciences',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/173610839',
#    'PublicationMedlineTA': 'Educ Sci (Basel)',
#    'PublicationSource': [{'PMID': '28835879',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28835879'}],
#    'PublicationTitle': "Ben-Zeev A, Paluy Y, Milless KL, Goldstein EJ, Wallace L, Márquez-Magaña L, Bibbins-Domingo K, Estrada M. 'Speaking Truth' Protects Underrepresented Minorities' Intellectual Performance and Safety in STEM. Educ Sci (Basel). 2017 Jun; 7(2).",
#    'Title': "'Speaking Truth' Protects Underrepresented Minorities' Intellectual Performance and Safety in STEM.",
#    'Year': '2017'},
#   {'AuthorList': 'Chen TK, Estrella MM, Vittinghoff E, Lin F, Gutierrez OM, Kramer H, Lewis CE, Kopp JB, Allen NB, Winkler CA, Bibbins-Domingo KB, Peralta CA',
#    'Claimed': True,
#    'Date': '2017-05-23T00:00:00',
#    'Featured': None,
#    'Publication': 'Kidney international',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/162263094',
#    'PublicationMedlineTA': 'Kidney Int',
#    'PublicationSource': [{'PMID': '28545715',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28545715'}],
#    'PublicationTitle': 'Chen TK, Estrella MM, Vittinghoff E, Lin F, Gutierrez OM, Kramer H, Lewis CE, Kopp JB, Allen NB, Winkler CA, Bibbins-Domingo KB, Peralta CA. APOL1 genetic variants are not associated with longitudinal blood pressure in young black adults. Kidney Int. 2017 Oct; 92(4):964-971.',
#    'Title': 'APOL1 genetic variants are not associated with longitudinal blood pressure in young black adults.',
#    'Year': '2017'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ',
#    'Claimed': True,
#    'Date': '2017-05-16T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/149329132',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28397958',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28397958'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ. The US Preventive Services Task Force 2017 Draft Recommendation Statement on Screening for Prostate Cancer: An Invitation to Review and Comment. JAMA. 2017 May 16; 317(19):1949-1950.',
#    'Title': 'The US Preventive Services Task Force 2017 Draft Recommendation Statement on Screening for Prostate Cancer: An Invitation to Review and Comment.',
#    'Year': '2017'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Siu AL, Tseng CW',
#    'Claimed': True,
#    'Date': '2017-05-09T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/162263095',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28492905',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28492905'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Siu AL, Tseng CW. Screening for Thyroid Cancer: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 May 09; 317(18):1882-1887.',
#    'Title': 'Screening for Thyroid Cancer: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2017'},
#   {'AuthorList': 'Kramer H, Colangelo L, Lewis CE, Jacobs DR, Pletcher M, Bibbins-Domingo K, Chang A, Siscovick D, Shlipak M, Peralta CA, Bansal N, Muntner P, Liu K',
#    'Claimed': True,
#    'Date': '2017-05-01T00:00:00',
#    'Featured': None,
#    'Publication': 'American journal of hypertension',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/146064005',
#    'PublicationMedlineTA': 'Am J Hypertens',
#    'PublicationSource': [{'PMID': '28338726',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28338726'}],
#    'PublicationTitle': 'Kramer H, Colangelo L, Lewis CE, Jacobs DR, Pletcher M, Bibbins-Domingo K, Chang A, Siscovick D, Shlipak M, Peralta CA, Bansal N, Muntner P, Liu K. Cumulative Exposure to Systolic Blood Pressure During Young Adulthood Through Midlife and the Urine Albumin-to-Creatinine Ratio at Midlife. Am J Hypertens. 2017 May 01; 30(5):502-509.',
#    'Title': 'Cumulative Exposure to Systolic Blood Pressure During Young Adulthood Through Midlife and the Urine Albumin-to-Creatinine Ratio at Midlife.',
#    'Year': '2017'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#    'Claimed': True,
#    'Date': '2017-04-25T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/152493885',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28444286',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28444286'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon MA, Tseng CW. Screening for Preeclampsia: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Apr 25; 317(16):1661-1667.',
#    'Title': 'Screening for Preeclampsia: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2017'},
#   {'AuthorList': 'Lunn MR, Obedin-Maliver J, Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2017-04-25T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/152493886',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28444268',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28444268'}],
#    'PublicationTitle': 'Lunn MR, Obedin-Maliver J, Bibbins-Domingo K. Estimating the Prevalence of Sexual Minority Adolescents. JAMA. 2017 04 25; 317(16):1691-1692.',
#    'Title': 'Estimating the Prevalence of Sexual Minority Adolescents.',
#    'Year': '2017'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Ebell M, Epling JW, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW',
#    'Claimed': True,
#    'Date': '2017-03-28T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/146978504',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28350936',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28350936'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Ebell M, Epling JW, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phipps MG, Silverstein M, Simon MA, Tseng CW. Screening for Celiac Disease: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 03 28; 317(12):1252-1257.',
#    'Title': 'Screening for Celiac Disease: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2017'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon M, Siu AL, Tseng CW',
#    'Claimed': True,
#    'Date': '2017-03-07T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/143536187',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28267862',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28267862'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Barry MJ, Davidson KW, Doubeni CA, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Silverstein M, Simon M, Siu AL, Tseng CW. Screening for Gynecologic Conditions With Pelvic Examination: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 03 07; 317(9):947-953.',
#    'Title': 'Screening for Gynecologic Conditions With Pelvic Examination: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2017'},
#   {'AuthorList': 'Bibbins-Domingo K, Whitlock E, Wolff T, Ngo-Metzger Q, Phillips WR, Davidson KW, Krist AH, Lin JS, Mangione CM, Kurth AE, García FAR, Curry SJ, Grossman DC, Landefeld CS, Epling JW, Siu AL',
#    'Claimed': True,
#    'Date': '2017-03-07T00:00:00',
#    'Featured': None,
#    'Publication': 'Annals of internal medicine',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/143536188',
#    'PublicationMedlineTA': 'Ann Intern Med',
#    'PublicationSource': [{'PMID': '28265649',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28265649'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Whitlock E, Wolff T, Ngo-Metzger Q, Phillips WR, Davidson KW, Krist AH, Lin JS, Mangione CM, Kurth AE, García FAR, Curry SJ, Grossman DC, Landefeld CS, Epling JW, Siu AL. Developing Recommendations for Evidence-Based Clinical Preventive Services for Diverse Populations: Methods of the U.S. Preventive Services Task Force. Ann Intern Med. 2017 Apr 18; 166(8):565-571.',
#    'Title': 'Developing Recommendations for Evidence-Based Clinical Preventive Services for Diverse Populations: Methods of the U.S. Preventive Services Task Force.',
#    'Year': '2017'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW',
#    'Claimed': True,
#    'Date': '2017-01-24T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/140712977',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28118461',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28118461'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW. Screening for Obstructive Sleep Apnea in Adults: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 Jan 24; 317(4):407-414.',
#    'Title': 'Screening for Obstructive Sleep Apnea in Adults: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2017'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW',
#    'Claimed': True,
#    'Date': '2017-01-10T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/137209449',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '28097362',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28097362'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW. Folic Acid Supplementation for the Prevention of Neural Tube Defects: US Preventive Services Task Force Recommendation Statement. JAMA. 2017 01 10; 317(2):183-189.',
#    'Title': 'Folic Acid Supplementation for the Prevention of Neural Tube Defects: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2017'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW',
#    'Claimed': True,
#    'Date': '2016-12-20T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/133369762',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '27997659',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27997659'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP, Silverstein M, Tseng CW. Serologic Screening for Genital Herpes Infection: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 12 20; 316(23):2525-2530.',
#    'Title': 'Serologic Screening for Genital Herpes Infection: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2016'},
#   {'AuthorList': 'Grubbs V, Garcia F, Jue BL, Vittinghoff E, Ryder M, Lovett D, Carrillo J, Offenbacher S, Ganz P, Bibbins-Domingo K, Powe NR',
#    'Claimed': True,
#    'Date': '2016-12-20T00:00:00',
#    'Featured': None,
#    'Publication': 'Contemporary clinical trials',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/133369835',
#    'PublicationMedlineTA': 'Contemp Clin Trials',
#    'PublicationSource': [{'PMID': '28011387',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/28011387'}],
#    'PublicationTitle': 'Grubbs V, Garcia F, Jue BL, Vittinghoff E, Ryder M, Lovett D, Carrillo J, Offenbacher S, Ganz P, Bibbins-Domingo K, Powe NR. The Kidney and Periodontal Disease (KAPD) study: A pilot randomized controlled trial testing the effect of non-surgical periodontal therapy on chronic kidney disease. Contemp Clin Trials. 2017 Feb; 53:143-150.',
#    'Title': 'The Kidney and Periodontal Disease (KAPD) study: A pilot randomized controlled trial testing the effect of non-surgical periodontal therapy on chronic kidney disease.',
#    'Year': '2016'},
#   {'AuthorList': 'Oh SS, Du R, Zeiger AM, McGarry ME, Hu D, Thakur N, Pino-Yanes M, Galanter JM, Eng C, Nishimura KK, Huntsman S, Farber HJ, Meade K, Avila P, Serebrisky D, Bibbins-Domingo K, Lenoir MA, Ford JG, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne SM, Sen S, Rodriguez-Santana JR, Williams K, Kumar R, Burchard EG',
#    'Claimed': True,
#    'Date': '2016-12-08T00:00:00',
#    'Featured': None,
#    'Publication': 'The Journal of asthma : official journal of the Association for the Care of Asthma',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/132444909',
#    'PublicationMedlineTA': 'J Asthma',
#    'PublicationSource': [{'PMID': '27929698',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27929698'}],
#    'PublicationTitle': 'Oh SS, Du R, Zeiger AM, McGarry ME, Hu D, Thakur N, Pino-Yanes M, Galanter JM, Eng C, Nishimura KK, Huntsman S, Farber HJ, Meade K, Avila P, Serebrisky D, Bibbins-Domingo K, Lenoir MA, Ford JG, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne SM, Sen S, Rodriguez-Santana JR, Williams K, Kumar R, Burchard EG. Breastfeeding associated with higher lung function in African American youths with asthma. J Asthma. 2016 Dec 08; 1-10.',
#    'Title': 'Breastfeeding associated with higher lung function in African American youths with asthma.',
#    'Year': '2016'},
#   {'AuthorList': 'Thakur N, Barcelo NE, Borrell LN, Singh S, Eng C, Davis A, Meade K, LeNoir MA, Avila PC, Farber HJ, Serebrisky D, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne S, Rodriguez-Santana JR, Sen S, Bibbins-Domingo K, Burchard EG',
#    'Claimed': True,
#    'Date': '2016-12-01T00:00:00',
#    'Featured': None,
#    'Publication': 'Chest',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/136107302',
#    'PublicationMedlineTA': 'Chest',
#    'PublicationSource': [{'PMID': '27916618',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27916618'}],
#    'PublicationTitle': 'Thakur N, Barcelo NE, Borrell LN, Singh S, Eng C, Davis A, Meade K, LeNoir MA, Avila PC, Farber HJ, Serebrisky D, Brigino-Buenaventura E, Rodriguez-Cintron W, Thyne S, Rodriguez-Santana JR, Sen S, Bibbins-Domingo K, Burchard EG. Perceived Discrimination Associated With Asthma and Related Outcomes in Minority Youth: The GALA II and SAGE II Studies. Chest. 2017 Apr; 151(4):804-812.',
#    'Title': 'Perceived Discrimination Associated With Asthma and Related Outcomes in Minority Youth: The GALA II and SAGE II Studies.',
#    'Year': '2016'},
#   {'AuthorList': 'Zaitlen N, Huntsman S, Hu D, Spear M, Eng C, Oh SS, White MJ, Mak A, Davis A, Meade K, Brigino-Buenaventura E, LeNoir MA, Bibbins-Domingo K, Burchard EG, Halperin E',
#    'Claimed': True,
#    'Date': '2016-11-22T00:00:00',
#    'Featured': None,
#    'Publication': 'Genetics',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/129242115',
#    'PublicationMedlineTA': 'Genetics',
#    'PublicationSource': [{'PMID': '27879348',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27879348'}],
#    'PublicationTitle': 'Zaitlen N, Huntsman S, Hu D, Spear M, Eng C, Oh SS, White MJ, Mak A, Davis A, Meade K, Brigino-Buenaventura E, LeNoir MA, Bibbins-Domingo K, Burchard EG, Halperin E. The Effects of Migration and Assortative Mating on Admixture Linkage Disequilibrium. Genetics. 2017 Jan; 205(1):375-383.',
#    'Title': 'The Effects of Migration and Assortative Mating on Admixture Linkage Disequilibrium.',
#    'Year': '2016'},
#   {'AuthorList': 'Kazi DS, Moran AE, Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2016-11-22T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/130513267',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '27893125',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27893125'}],
#    'PublicationTitle': 'Kazi DS, Moran AE, Bibbins-Domingo K. Cost-effectiveness of PCSK9 Inhibitor Therapy-Reply. JAMA. 2016 Nov 22; 316(20):2152.',
#    'Title': 'Cost-effectiveness of PCSK9 Inhibitor Therapy-Reply.',
#    'Year': '2016'},
#   {'AuthorList': 'Konfino J, Fernandez A, Penko J, Mason A, Martinez E, Coxson P, Heller D, Moran A, Bibbins-Domingo K, Pérez-Stable EJ, Mejía R',
#    'Claimed': True,
#    'Date': '2016-11-16T00:00:00',
#    'Featured': None,
#    'Publication': 'Journal of general internal medicine',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/128265828',
#    'PublicationMedlineTA': 'J Gen Intern Med',
#    'PublicationSource': [{'PMID': '27853916',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27853916'}],
#    'PublicationTitle': 'Konfino J, Fernandez A, Penko J, Mason A, Martinez E, Coxson P, Heller D, Moran A, Bibbins-Domingo K, Pérez-Stable EJ, Mejía R. Comparing Strategies for Lipid Lowering in Argentina: An Analysis from the CVD Policy Model-Argentina. J Gen Intern Med. 2017 May; 32(5):524-533.',
#    'Title': 'Comparing Strategies for Lipid Lowering in Argentina: An Analysis from the CVD Policy Model-Argentina.',
#    'Year': '2016'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Gillman MW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, LeFevre ML, Mangione CM, Phillips WR, Owens DK, Phipps MG, Pignone MP',
#    'Claimed': True,
#    'Date': '2016-11-15T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/127816615',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '27838723',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27838723'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Gillman MW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, LeFevre ML, Mangione CM, Phillips WR, Owens DK, Phipps MG, Pignone MP. Statin Use for the Primary Prevention of Cardiovascular Disease in Adults: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 Nov 15; 316(19):1997-2007.',
#    'Title': 'Statin Use for the Primary Prevention of Cardiovascular Disease in Adults: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2016'},
#   {'AuthorList': 'Georgiopoulou VV, Kalogeropoulos AP, Chowdhury R, Binongo JN, Bibbins-Domingo K, Rodondi N, Simonsick EM, Harris T, Newman AB, Kritchevsky SB, Butler J',
#    'Claimed': True,
#    'Date': '2016-11-14T00:00:00',
#    'Featured': None,
#    'Publication': 'American journal of preventive medicine',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/128265852',
#    'PublicationMedlineTA': 'Am J Prev Med',
#    'PublicationSource': [{'PMID': '27856115',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27856115'}],
#    'PublicationTitle': 'Georgiopoulou VV, Kalogeropoulos AP, Chowdhury R, Binongo JN, Bibbins-Domingo K, Rodondi N, Simonsick EM, Harris T, Newman AB, Kritchevsky SB, Butler J. Exercise Capacity, Heart Failure Risk, and Mortality in Older Adults: The Health ABC Study. Am J Prev Med. 2017 Feb; 52(2):144-153.',
#    'Title': 'Exercise Capacity, Heart Failure Risk, and Mortality in Older Adults: The Health ABC Study.',
#    'Year': '2016'},
#   {'AuthorList': 'Sánchez-Romero LM, Penko J, Coxson PG, Fernández A, Mason A, Moran AE, Ávila-Burgos L, Odden M, Barquera S, Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2016-11-01T00:00:00',
#    'Featured': None,
#    'Publication': 'PLoS medicine',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/125550651',
#    'PublicationMedlineTA': 'PLoS Med',
#    'PublicationSource': [{'PMID': '27802278',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27802278'}],
#    'PublicationTitle': "Sánchez-Romero LM, Penko J, Coxson PG, Fernández A, Mason A, Moran AE, Ávila-Burgos L, Odden M, Barquera S, Bibbins-Domingo K. Projected Impact of Mexico's Sugar-Sweetened Beverage Tax Policy on Diabetes and Cardiovascular Disease: A Modeling Study. PLoS Med. 2016 Nov; 13(11):e1002158.",
#    'Title': "Projected Impact of Mexico's Sugar-Sweetened Beverage Tax Policy on Diabetes and Cardiovascular Disease: A Modeling Study.",
#    'Year': '2016'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP',
#    'Claimed': True,
#    'Date': '2016-10-25T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/125550647',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '27784102',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27784102'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP. Primary Care Interventions to Support Breastfeeding: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 10 25; 316(16):1688-1693.',
#    'Title': 'Primary Care Interventions to Support Breastfeeding: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2016'},
#   {'AuthorList': 'Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2016-10-25T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/125550648',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '27784091',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27784091'}],
#    'PublicationTitle': 'Bibbins-Domingo K. Colorectal Cancer Screening Recommendations-Reply. JAMA. 2016 Oct 25; 316(16):1717.',
#    'Title': 'Colorectal Cancer Screening Recommendations-Reply.',
#    'Year': '2016'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Bauman L, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP',
#    'Claimed': True,
#    'Date': '2016-09-06T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/119164730',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '27599331',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27599331'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Bauman L, Davidson KW, Epling JW, García FA, Herzstein J, Kemper AR, Krist AH, Kurth AE, Landefeld CS, Mangione CM, Phillips WR, Phipps MG, Pignone MP. Screening for Latent Tuberculosis Infection in Adults: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 Sep 06; 316(9):962-9.',
#    'Title': 'Screening for Latent Tuberculosis Infection in Adults: US Preventive Services Task Force Recommendation Statement.',
#    'Year': '2016'},
#   {'AuthorList': 'Kazi DS, Moran AE, Coxson PG, Penko J, Ollendorf DA, Pearson SD, Tice JA, Guzman D, Bibbins-Domingo K',
#    'Claimed': True,
#    'Date': '2016-08-16T00:00:00',
#    'Featured': '1',
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/116246030',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '27533159',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27533159'}],
#    'PublicationTitle': 'Kazi DS, Moran AE, Coxson PG, Penko J, Ollendorf DA, Pearson SD, Tice JA, Guzman D, Bibbins-Domingo K. Cost-effectiveness of PCSK9 Inhibitor Therapy in Patients With Heterozygous Familial Hypercholesterolemia or Atherosclerotic Cardiovascular Disease. JAMA. 2016 Aug 16; 316(7):743-53.',
#    'Title': 'Cost-effectiveness of PCSK9 Inhibitor Therapy in Patients With Heterozygous Familial Hypercholesterolemia or Atherosclerotic Cardiovascular Disease.',
#    'Year': '2016'},
#   {'AuthorList': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Gillman MW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, LeFevre M, Mangione CM, Owens DK, Phillips WR, Phipps MG, Pignone MP, Siu AL',
#    'Claimed': True,
#    'Date': '2016-08-09T00:00:00',
#    'Featured': None,
#    'Publication': 'JAMA',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/116246031',
#    'PublicationMedlineTA': 'JAMA',
#    'PublicationSource': [{'PMID': '27532917',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/27532917'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Grossman DC, Curry SJ, Davidson KW, Epling JW, García FA, Gillman MW, Kemper AR, Krist AH, Kurth AE, Landefeld CS, LeFevre M, Mangione CM, Owens DK, Phillips WR, Phipps MG, Pignone MP, Siu AL. Screening for Lipid Disorders in Children and Adolescents: US Preventive Services Task Force Recommendation Statement. JAMA. 2016 Aug 09; 316(6):625-33.',
# ...
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/17200222'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Fernandez A. BiDil for heart failure in black patients: implications of the U.S. Food and Drug Administration approval. Ann Intern Med. 2007 Jan 02; 146(1):52-6.',
#    'Title': 'BiDil for heart failure in black patients: implications of the U.S. Food and Drug Administration approval.',
#    'Year': '2007'},
#   {'AuthorList': 'Bibbins-Domingo K, Chertow GM, Fried LF, Odden MC, Newman AB, Kritchevsky SB, Harris TB, Satterfield S, Cummings SR, Shlipak MG',
#    'Claimed': True,
#    'Date': '2006-07-10T00:00:00',
#    'Featured': None,
#    'Publication': 'Archives of internal medicine',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/324786',
#    'PublicationMedlineTA': 'Arch Intern Med',
#    'PublicationSource': [{'PMID': '16832005',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/16832005'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Chertow GM, Fried LF, Odden MC, Newman AB, Kritchevsky SB, Harris TB, Satterfield S, Cummings SR, Shlipak MG. Renal function and heart failure risk in older black and white individuals: the Health, Aging, and Body Composition Study. Arch Intern Med. 2006 Jul 10; 166(13):1396-402.',
#    'Title': 'Renal function and heart failure risk in older black and white individuals: the Health, Aging, and Body Composition Study.',
#    'Year': '2006'},
#   {'AuthorList': 'Piette JD, Bibbins-Domingo K, Schillinger D',
#    'Claimed': True,
#    'Date': '2005-01-21T00:00:00',
#    'Featured': None,
#    'Publication': 'Patient education and counseling',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/323448',
#    'PublicationMedlineTA': 'Patient Educ Couns',
#    'PublicationSource': [{'PMID': '16332469',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/16332469'}],
#    'PublicationTitle': "Piette JD, Bibbins-Domingo K, Schillinger D. Health care discrimination, processes of care, and diabetes patients' health status. Patient Educ Couns. 2006 Jan; 60(1):41-8.",
#    'Title': "Health care discrimination, processes of care, and diabetes patients' health status.",
#    'Year': '2005'},
#   {'AuthorList': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG',
#    'Claimed': True,
#    'Date': '2005-01-15T00:00:00',
#    'Featured': None,
#    'Publication': 'The American journal of cardiology',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/321446',
#    'PublicationMedlineTA': 'Am J Cardiol',
#    'PublicationSource': [{'PMID': '15642574',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15642574'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG. Effect of hormone therapy on mortality rates among women with heart failure and coronary artery disease. Am J Cardiol. 2005 Jan 15; 95(2):289-91.',
#    'Title': 'Effect of hormone therapy on mortality rates among women with heart failure and coronary artery disease.',
#    'Year': '2005'},
#   {'AuthorList': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Grady D, Shlipak MG',
#    'Claimed': True,
#    'Date': '2004-10-19T00:00:00',
#    'Featured': None,
#    'Publication': 'Journal of the American College of Cardiology',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/321003',
#    'PublicationMedlineTA': 'J Am Coll Cardiol',
#    'PublicationSource': [{'PMID': '15489091',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15489091'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Grady D, Shlipak MG. Renal insufficiency as an independent predictor of mortality among women with heart failure. J Am Coll Cardiol. 2004 Oct 19; 44(8):1593-600.',
#    'Title': 'Renal insufficiency as an independent predictor of mortality among women with heart failure.',
#    'Year': '2004'},
#   {'AuthorList': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG',
#    'Claimed': True,
#    'Date': '2004-09-07T00:00:00',
#    'Featured': None,
#    'Publication': 'Circulation',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/272249',
#    'PublicationMedlineTA': 'Circulation',
#    'PublicationSource': [{'PMID': '15353499',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15353499'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Lin F, Vittinghoff E, Barrett-Connor E, Hulley SB, Grady D, Shlipak MG. Predictors of heart failure among women with coronary disease. Circulation. 2004 Sep 14; 110(11):1424-30.',
#    'Title': 'Predictors of heart failure among women with coronary disease.',
#    'Year': '2004'},
#   {'AuthorList': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA',
#    'Claimed': True,
#    'Date': '2004-04-15T00:00:00',
#    'Featured': None,
#    'Publication': 'The American journal of medicine',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/319953',
#    'PublicationMedlineTA': 'Am J Med',
#    'PublicationSource': [{'PMID': '15063811',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/15063811'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA. Is B-type natriuretic peptide a useful screening test for systolic or diastolic dysfunction in patients with coronary disease? Data from the Heart and Soul Study. Am J Med. 2004 Apr 15; 116(8):509-16.',
#    'Title': 'Is B-type natriuretic peptide a useful screening test for systolic or diastolic dysfunction in patients with coronary disease? Data from the Heart and Soul Study.',
#    'Year': '2004'},
#   {'AuthorList': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA',
#    'Claimed': True,
#    'Date': '2003-12-08T00:00:00',
#    'Featured': None,
#    'Publication': 'Circulation',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/261298',
#    'PublicationMedlineTA': 'Circulation',
#    'PublicationSource': [{'PMID': '14662720',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/14662720'}],
#    'PublicationTitle': 'Bibbins-Domingo K, Ansari M, Schiller NB, Massie B, Whooley MA. B-type natriuretic peptide and ischemia in patients with stable coronary disease: data from the Heart and Soul study. Circulation. 2003 Dec 16; 108(24):2987-92.',
#    'Title': 'B-type natriuretic peptide and ischemia in patients with stable coronary disease: data from the Heart and Soul study.',
#    'Year': '2003'},
#   {'AuthorList': 'Schillinger D, Bibbins-Domingo K, Vranizan K, Bacchetti P, Luce JM, Bindman AB',
#    'Claimed': True,
#    'Date': '2000-05-01T00:00:00',
#    'Featured': None,
#    'Publication': 'Journal of general internal medicine',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/313775',
#    'PublicationMedlineTA': 'J Gen Intern Med',
#    'PublicationSource': [{'PMID': '10840268',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/10840268'}],
#    'PublicationTitle': 'Schillinger D, Bibbins-Domingo K, Vranizan K, Bacchetti P, Luce JM, Bindman AB. Effects of primary care coordination on public hospital patients. J Gen Intern Med. 2000 May; 15(5):329-36.',
#    'Title': 'Effects of primary care coordination on public hospital patients.',
#    'Year': '2000'},
#   {'AuthorList': 'Boeuf H, Murphy J, Bibbins KB, Varmus HE',
#    'Claimed': True,
#    'Date': '1995-02-02T00:00:00',
#    'Featured': None,
#    'Publication': 'Oncogene',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/241654',
#    'PublicationMedlineTA': 'Oncogene',
#    'PublicationSource': [{'PMID': '7531318',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/7531318'}],
#    'PublicationTitle': 'Boeuf H, Murphy J, Bibbins KB, Varmus HE. Binding in vitro of phosphotyrosine-containing proteins to pp60c-src SH2 domain does not correlate with CEF transformation. Oncogene. 1995 Feb 02; 10(3):433-8.',
#    'Title': 'Binding in vitro of phosphotyrosine-containing proteins to pp60c-src SH2 domain does not correlate with CEF transformation.',
#    'Year': '1995'},
#   {'AuthorList': 'Kaplan KB, Bibbins KB, Swedlow JR, Arnaud M, Morgan DO, Varmus HE',
#    'Claimed': True,
#    'Date': '1994-10-17T00:00:00',
#    'Featured': None,
#    'Publication': 'The EMBO journal',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/234511',
#    'PublicationMedlineTA': 'EMBO J',
#    'PublicationSource': [{'PMID': '7525268',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/7525268'}],
#    'PublicationTitle': 'Kaplan KB, Bibbins KB, Swedlow JR, Arnaud M, Morgan DO, Varmus HE. Association of the amino-terminal half of c-Src with focal adhesions alters their properties and is regulated by phosphorylation of tyrosine 527. EMBO J. 1994 Oct 17; 13(20):4745-56.',
#    'Title': 'Association of the amino-terminal half of c-Src with focal adhesions alters their properties and is regulated by phosphorylation of tyrosine 527.',
#    'Year': '1994'},
#   {'AuthorList': 'Bibbins KB, Boeuf H, Varmus HE',
#    'Claimed': True,
#    'Date': '1993-12-01T00:00:00',
#    'Featured': None,
#    'Publication': 'Molecular and cellular biology',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/234440',
#    'PublicationMedlineTA': 'Mol Cell Biol',
#    'PublicationSource': [{'PMID': '7504171',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/7504171'}],
#    'PublicationTitle': 'Bibbins KB, Boeuf H, Varmus HE. Binding of the Src SH2 domain to phosphopeptides is determined by residues in both the SH2 domain and the phosphopeptides. Mol Cell Biol. 1993 Dec; 13(12):7278-87.',
#    'Title': 'Binding of the Src SH2 domain to phosphopeptides is determined by residues in both the SH2 domain and the phosphopeptides.',
#    'Year': '1993'},
#   {'AuthorList': 'Bibbins KB, Tsai JY, Schimenti J, Sarvetnick N, Zoghbi HY, Goodfellow P, Silver LM',
#    'Claimed': True,
#    'Date': '1989-07-01T00:00:00',
#    'Featured': None,
#    'Publication': 'Genomics',
#    'PublicationCategory': None,
#    'PublicationID': 'http://profiles.ucsf.edu/profile/223263',
#    'PublicationMedlineTA': 'Genomics',
#    'PublicationSource': [{'PMID': '2767684',
#      'PublicationSourceName': 'PubMed',
#      'PublicationSourceURL': 'http://www.ncbi.nlm.nih.gov/pubmed/2767684'}],
#    'PublicationTitle': 'Bibbins KB, Tsai JY, Schimenti J, Sarvetnick N, Zoghbi HY, Goodfellow P, Silver LM. Human homologs of two testes-expressed loci on mouse chromosome 17 map to opposite arms of chromosome 6. Genomics. 1989 Jul; 5(1):139-43.',
#    'Title': 'Human homologs of two testes-expressed loci on mouse chromosome 17 map to opposite arms of chromosome 6.',
#    'Year': '1989'}],
#  'ResearchActivitiesAndFunding': [{'EndDate': '2022-08-31',
#    'Role': 'Principal Investigator',
#    'Sponsor': 'NIH/NHLBI',
#    'SponsorAwardID': 'K12HL138046',
#    'StartDate': '2017-09-01',
#    'Title': 'UCSF Career Development Program in Implementation Research in Heart and Lung Diseases'},
#   {'EndDate': '2021-05-31',
#    'Role': 'Principal Investigator',
#    'Sponsor': 'NIH/NCATS',
#    'SponsorAwardID': 'TL1TR001871',
#    'StartDate': '2016-07-18',
#    'Title': 'NRSA Training Core'},
#   {'EndDate': '2021-05-31',
#    'Role': 'Co-Principal Investigator',
#    'Sponsor': 'NIH/NCATS',
#    'SponsorAwardID': 'KL2TR001870',
#    'StartDate': '2016-07-18',
#    'Title': 'Institutional Career Development Core'},
#   {'EndDate': '2019-07-31',
#    'Role': 'Principal Investigator',
#    'Sponsor': 'NIH/NIDDK',
#    'SponsorAwardID': 'K24DK103992',
#    'StartDate': '2014-09-20',
#    'Title': 'Hypertension Management in Minority and Low-income Populations'},
#   {'EndDate': '2019-06-30',
#    'Role': 'Co-Principal Investigator',
#    'Sponsor': 'NIH/NIMHD',
#    'SponsorAwardID': 'TL4MD009638',
#    'StartDate': '2014-09-26',
#    'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#   {'EndDate': '2019-06-30',
#    'Role': 'Co-Principal Investigator',
#    'Sponsor': 'NIH/NIGMS',
#    'SponsorAwardID': 'UL1GM118985',
#    'StartDate': '2014-09-26',
#    'Title': 'SF BUILD: Enabling Students to Represnt in Science'},
#   {'EndDate': '2019-06-30',
#    'Role': 'Co-Principal Investigator',
#    'Sponsor': 'NIH/NIGMS',
#    'SponsorAwardID': 'RL5GM118984',
#    'StartDate': '2014-09-26',
#    'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#   {'EndDate': '2019-06-30',
#    'Role': 'Co-Principal Investigator',
#    'Sponsor': 'NIH/NIMHD',
#    'SponsorAwardID': 'RL5MD009599',
#    'StartDate': '2014-09-26',
#    'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#   {'EndDate': '2019-06-30',
#    'Role': 'Co-Principal Investigator',
#    'Sponsor': 'NIH/NIGMS',
#    'SponsorAwardID': 'TL4GM118986',
#    'StartDate': '2014-09-26',
#    'Title': 'SF BUILD: Enabling Students to Represent in Science'},
#   {'EndDate': '2019-06-30',
#    'Role': 'Co-Principal Investigator',
#    'Sponsor': 'NIH/NIMHD',
#    'SponsorAwardID': 'UL1MD009608',
#    'StartDate': '2014-09-26',
#    'Title': 'SF BUILD: Enabling Students to Represnt in Science'},
#   {'EndDate': '2018-06-30',
#    'Role': 'Co-Principal Investigator',
#    'Sponsor': 'NIH',
#    'SponsorAwardID': 'OT2OD025276',
#    'StartDate': '2017-07-23',
#    'Title': 'All of Us Research Program National Sexual and Gender Minority Engagement Network'},
#   {'EndDate': '2018-05-31',
#    'Role': 'Principal Investigator',
#    'Sponsor': 'NIH/NHLBI',
#    'SponsorAwardID': 'R25HL126146',
#    'StartDate': '2014-09-15',
#    'Title': 'UCSF Research in Implementation Sciences for Equity (RISE)'},
#   {'EndDate': '2017-08-31',
#    'Role': 'Co-Principal Investigator',
#    'Sponsor': 'NIH/NINDS',
#    'SponsorAwardID': 'U54NS081760',
#    'StartDate': '2012-09-30',
#    'Title': 'The Discovering Healthcare Innovations to Address Disparties in Stroke (DIADS) pr'},
#   {'EndDate': '2017-02-28',
#    'Role': 'Principal Investigator',
#    'Sponsor': 'NIH/NIMHD',
#    'SponsorAwardID': 'P60MD006902',
#    'StartDate': '2012-08-27',
#    'Title': 'Addressing disparities in chronic disease with a teen and young adult focus'},
#   {'EndDate': '2016-02-29',
#    'Role': 'Principal Investigator',
#    'Sponsor': 'NIH/FIC',
#    'SponsorAwardID': 'R03TW009061',
#    'StartDate': '2013-03-20',
#    'Title': 'Enhancing Mexican Capacity for CVD Policy Research'},
#   {'EndDate': '2012-07-31',
#    'Role': 'Principal Investigator',
#    'Sponsor': 'NIH/NIDDK',
#    'SponsorAwardID': 'R01DK078124',
#    'StartDate': '2008-08-01',
#    'Title': 'Chronic Kidney Disease and Cardiovascular Risk in Black and White Young Adults'}],
#  'School': 'UCSF School of Medicine',
#  'SlideShare_beta': [],
#  'Title': 'Professor',
#  'Titles': ['Professor'],
#  'Twitter_beta': ['ucsfcvp'],
#  'Videos': [{'label': 'Mission in a Minute',
#    'url': 'https://www.youtube.com/watch?v=DxLJwwvcg-o&index=1&list=PLVLbDUiGesPyQqgEEsceWk4-FzSmMeI_d'},
#   {'label': 'A Life in Medicine: People Shaping Healthcare Today',
#    'url': 'https://youtu.be/lzivJjGwPdU'}],
#  'WebLinks_beta': [{'Label': 'UCSF Center for Vulnerable Populations at San Francisco General Hospital',
#    'URL': 'http://cvp.ucsf.edu/'},
#   {'Label': 'UCSF CTSI K Scholars Program',
#    'URL': 'http://ctsi.ucsf.edu/our-work/k-scholars-program'},
#   {'Label': 'Sugar Science',
#    'URL': 'http://sugarscience.org/sugarscientist-team/#.VGFBsvTF-wA'},
#   {'Label': 'Bring It Down Stroke Study',
#    'URL': 'http://www.bringitdownstudy.org/'}]}

# %% [markdown]
# And in this case, we're back to dealing with a dictionary.  So far, we have a list containing dictionaries nested in a list.  Let's check the keys again.

# %%
profile.keys()
# Out:
# dict_keys(['Email', 'Titles', 'LastName', 'Keywords', 'Department', 'ResearchActivitiesAndFunding', 'ProfilesURL', 'PublicationCount', 'SlideShare_beta', 'Education_Training', 'MediaLinks_beta', 'WebLinks_beta', 'Name', 'Narrative', 'Twitter_beta', 'NIHGrants_beta', 'Title', 'School', 'FirstName', 'Publications', 'GlobalHealth_beta', 'AwardOrHonors', 'Videos', 'Address', 'FreetextKeywords', 'PhotoURL'])

# %% [markdown]
# We're back to a list, again, of length one (feel free to check as an exercise).  Let's grab the first (and only) element here...

# %%
profileData = profiles[0]

# %% [markdown]
# ... and take a look at the keys

# %%
profileData.keys()
# Out:
# dict_keys(['Email', 'Titles', 'LastName', 'Keywords', 'Department', 'ResearchActivitiesAndFunding', 'ProfilesURL', 'PublicationCount', 'SlideShare_beta', 'Education_Training', 'MediaLinks_beta', 'WebLinks_beta', 'Name', 'Narrative', 'Twitter_beta', 'NIHGrants_beta', 'Title', 'School', 'FirstName', 'Publications', 'GlobalHealth_beta', 'AwardOrHonors', 'Videos', 'Address', 'FreetextKeywords', 'PhotoURL'])

# %% [markdown]
# At this point, you might want to try looking into different elemets of this list.  Some are data points, containing no further nested data, others contain lists or dictionaries.  we'll take a closer look at **ResearchActivitiesAndFunding**.

# %%
researchAndFunding = profileData['ResearchActivitiesAndFunding']

# %% [markdown]
# This key maps to a list, this time with a larger (and, it turns out, variable) number of entries.

# %%
len(researchAndFunding)
# Out:
# 16

# %% [markdown]
# Let's take a look at the first

# %%
researchAndFundingData = researchAndFunding[0]

# %%
researchAndFundingData
# Out:
# {'EndDate': '2022-08-31',
#  'Role': 'Principal Investigator',
#  'Sponsor': 'NIH/NHLBI',
#  'SponsorAwardID': 'K12HL138046',
#  'StartDate': '2017-09-01',
#  'Title': 'UCSF Career Development Program in Implementation Research in Heart and Lung Diseases'}

# %% [markdown]
# You can see, from the key and value pairs, that this dictionary does not contain any further nested data, each key maps to a string value.

# %% [markdown]
# From this final node in the JSON tree, we can get at the metadata for a particular publication, including the publication Title.

# %%
researchAndFundingData['Title']
# Out:
# 'UCSF Career Development Program in Implementation Research in Heart and Lung Diseases'

# %% [markdown]
# ***Exercise***
#
# Try wr
